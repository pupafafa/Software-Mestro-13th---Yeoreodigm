# %% [markdown]
# #추천함수

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recommend_by_theme(df,id,top):
  tag = ['nature','outdoor','fatigue','sea','walking','exciting','day','culture']

  try:
    target_index = df[df['Package_Id']==id].index.values
  except:
    target_index = df[df['id']==id].index.values
  print(target_index)
  total_similarity = cosine_similarity(df[tag])
  print(total_similarity.shape)
  similarity = total_similarity[target_index]
  similarity = list(similarity[0])
  
  
  print('similarity : ',similarity)
  
  similarity_with_index = [(val,idx) for idx,val in enumerate(similarity)]
  similarity_with_index.sort(reverse = True) 
  print("similarity_with_index : ",similarity_with_index)


  result_index = [i[1] for i in similarity_with_index]
  print("result_index : ",result_index)

  #자기 자신은 제외 (1일것임)
  me=0
  top_N_result = result_index[me:top+1] #자기 자신은 제외하려면 me -> me+1로 해주면 됨
  print(top_N_result)
  

  result = df.iloc[top_N_result]
  try:    
    return result.sort_values(by='score')
  except:
    return result

# %% [markdown]
# #aws s3에서 csv 파일 읽어오기

# %%
pip install boto3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting boto3
#   Using cached boto3-1.24.38-py3-none-any.whl (132 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Using cached s3transfer-0.6.0-py3-none-any.whl (79 kB)
# Collecting botocore<1.28.0,>=1.27.38
#   Using cached botocore-1.27.38-py3-none-any.whl (9.0 MB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.28.0,>=1.27.38->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.7/dist-packages (from botocore<1.28.0,>=1.27.38->boto3) (1.26.11)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.28.0,>=1.27.38->boto3) (1.15.0)
# Installing collected packages: botocore, s3transfer, boto3
# Successfully installed boto3-1.24.38 botocore-1.27.38 s3transfer-0.6.0

# %%
import pandas as pd
import boto3
import io
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-85d388b97c0c> in <module>()
#       1 import pandas as pd
# ----> 2 import boto3
#       3 import io
#       4 import os
#
# ModuleNotFoundError: No module named 'boto3'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def load_data_file():
  ACCESS_KEY_ID = "AKIAQU2ISDLMDGCFLS7A"
  SECRET_ACESS_KEY = "ZCWTR19N6IEhiL9PR1hebvLWqyrWTtmehdJtCh4D"

  client = boto3.client('s3')

  bucket_name = 'test-pandas-wonseok'

  object_key = '07.18_course_db'
  s3_client = boto3.client(service_name='s3', aws_access_key_id=ACCESS_KEY_ID, aws_secret_access_key=SECRET_ACESS_KEY)
  obj = s3_client.get_object(Bucket=bucket_name,Key=object_key)


  df = pd.read_csv(io.BytesIO(obj["Body"].read()))
  return df

# %%
db = load_data_file()

# %%
id = "DCKC2TKO3"
result = db.loc[db['Package_Id']==id,'Package_Id']
print(list(result))

# %% [markdown]
# #db에서 sql querry 날려서 dataframe으로 만들기

# %%
pip install psycopg2

# %%
import psycopg2

# %%
def load_db():
  with open("/content/drive/MyDrive/yeoreodigm/data_files/db_info.json") as json_file:
    DB_INFO = json.load(json_file)
  
  endpoint = DB_INFO["ENDPOINT"]
  dbname = DB_INFO["DB_NAME"]
  user = DB_INFO["USER_ID"]
  password = DB_INFO["PASSWORD"]
  db = psycopg2.connect(host=endpoint,dbname=dbname,user=user,password=password)
  return db

# %%
db = load_db()
cursor = db.cursor()

# %%
cursor.close()
db.close()

# %%
#id = 'CONT_000000000500281'
#sql= f'SELECT * from tourist_attraction where id = \'{id}\' order by score desc'
sql= f'SELECT id,title from tourist_attraction order by score desc;'
cursor.execute(sql)
result = cursor.fetchall()
print(result)
# result = list(map(lambda x: x[0], result))
# print(result)

# %%
import pandas as pd

# %%
result_list = pd.DataFrame(result)

# %%
result_list

# %%
result_list.columns=['id','title']
result_list

# %% [markdown]
# #로컬 python 파일 테스트

# %%
pip install boto3

# %%
pip install psycopg2

# %%
import json

import pandas as pd
import boto3
import io
import psycopg2
from sklearn.metrics.pairwise import cosine_similarity


def recommend_by_theme(df,id,top):
  tag = ['nature','outdoor','fatigue','sea','walking','exciting','day','culture']

  try:
    target_index = df[df['Package_Id']==id].index.values
  except:
    target_index = df[df['id']==id].index.values
  print(target_index)
  total_similarity = cosine_similarity(df[tag])
  print(total_similarity.shape)
  similarity = total_similarity[target_index]
  similarity = list(similarity[0])
  
  
  print('similarity : ',similarity)
  
  similarity_with_index = [(val,idx) for idx,val in enumerate(similarity)]
  similarity_with_index.sort(reverse = True) 
  print("similarity_with_index : ",similarity_with_index)


  result_index = [i[1] for i in similarity_with_index]
  print("result_index : ",result_index)

  #자기 자신은 제외 (1일것임)
  me=0
  top_N_result = result_index[me:top+1] #자기 자신은 제외하려면 me -> me+1로 해주면 됨
  print(top_N_result)
  

  result = df.iloc[top_N_result]
  try:    
    return result.sort_values(by='score')
  except:
    return result


def load_data_file():
  ACCESS_KEY_ID = "AKIAQU2ISDLMDGCFLS7A"
  SECRET_ACESS_KEY = "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"
  
  client = boto3.client('s3')
  
  bucket_name = 'test-pandas-wonseok'
  
  object_key = '07.18_course_db'
  s3_client = boto3.client(service_name='s3', aws_access_key_id=ACCESS_KEY_ID, aws_secret_access_key=SECRET_ACESS_KEY)
  obj = s3_client.get_object(Bucket=bucket_name,Key=object_key)
  df = pd.read_csv(io.BytesIO(obj["Body"].read()))
  
  return df
  
  
def load_db():
  with open("/content/drive/MyDrive/yeoreodigm/data_files/db_info.json") as json_file:
    DB_INFO = json.load(json_file)
  
  endpoint = DB_INFO["ENDPOINT"]
  dbname = DB_INFO["DB_NAME"]
  user = DB_INFO["USER_ID"]
  password = DB_INFO["PASSWORD"]
  db = psycopg2.connect(host=endpoint,dbname=dbname,user=user,password=password)
  return db
  



def lambda_handler(event, context):

  id = event['queryStringParameters']['id']
  type = event['queryStringParameters']['type']
  limit = int(event['queryStringParameters']['limit'])

#   db = load_db()
#   cursor = db.cursor()
#   sql= f'SELECT id,title from tourist_attraction order by score desc;'
  course = load_data_file()
  course = course.loc[(course['len']>limit-3) and (course['len']<limit+3)]
  
  result = recommend_by_theme(course,id,10)
  result = list(result['Package_Id'])

  
  result_list = []
  return {
      'statusCode': 200,
      
      'body': json.dumps({ "id": result,
                            })
  }

# %%
id = 'DCKC2TKO3'
limit = 5
course = load_data_file()
course = course.loc[((course['len']>limit-3) & (course['len']<limit+3))]

result = recommend_by_theme(course,id,10)
result_list = list(result['Package_Id'])

# %%
result

# %%
result

# %% [markdown]
# #테스트

# %%
import json
import io
import psycopg2
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
# Out:
# /usr/local/lib/python3.7/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
def recommend_by_theme(df,id,top):
  tag = ['nature','outdoor','fatigue','sea','walking','exciting','day','culture']

  try:
    target_index = df[df['Package_Id']==id].index.values
  except:
    target_index = df[df['id']==id].index.values
  print(target_index)
  total_similarity = cosine_similarity(df[tag])
  print(total_similarity.shape)
  similarity = total_similarity[target_index]
  similarity = list(similarity[0])
  
  
  print('similarity : ',similarity)
  
  similarity_with_index = [(val,idx) for idx,val in enumerate(similarity)]
  similarity_with_index.sort(reverse = True) 
  print("similarity_with_index : ",similarity_with_index)


  result_index = [i[1] for i in similarity_with_index]
  print("result_index : ",result_index)

  #자기 자신은 제외 (1일것임)
  me=0
  top_N_result = result_index[me:top+1] #자기 자신은 제외하려면 me -> me+1로 해주면 됨
  print(top_N_result)
  

  result = df.iloc[top_N_result]
  try:    
    return result.sort_values(by='score')
  except:
    return result

# %%
def load_db():
  with open("/content/drive/MyDrive/yeoreodigm/data_files/db_info.json") as json_file:
    DB_INFO = json.load(json_file)
  
  endpoint = DB_INFO["ENDPOINT"]
  dbname = DB_INFO["DB_NAME"]
  user = DB_INFO["USER_ID"]
  password = DB_INFO["PASSWORD"]
  db = psycopg2.connect(host=endpoint,dbname=dbname,user=user,password=password)
  return db

# %%
db = load_db()
cursor = db.cursor()
sample_sql =  f'SELECT id,title,nature,outdoor,fatigue,sea,walking,exciting,day,culture from tourist_attraction order by score desc;'
cursor.execute(sample_sql)
result = cursor.fetchall()
df = pd.DataFrame(result)
df.columns = ['id','title','nature','outdoor','fatigue','sea','walking','exciting','day','culture']
recommend = recommend_by_theme(df,'CONT_000000000500281',10)
recommend = recommend['id']
print(recommend)
# Out:
# [0]
# (1089, 1089)
# similarity :  [1.0, 0.8242255917447338, 0.7912565680749444, 0.803194840135015, 0.8295150620062531, 0.7756717518813396, 0.5642880936468346, 0.7842934903910445, 0.8242255917447338, 0.912870929175277, 0.8571593913749194, 0.8391463916782738, 0.828078671210825, 0.7912565680749444, 0.5669467095138407, 0.6902684899626333, 0.7877263614433762, 0.7889320586105297, 0.8198915917499228, 0.8295150620062531, 0.7999999999999999, 0.8198915917499228, 0.8183932073645681, 0.8381163549234939, 0.8391463916782738, 0.8571593913749194, 0.7912565680749444, 0.8693182879212227, 0.66688592885535, 0.7889320586105297, 0.8391463916782738, 0.8436614877321074, 0.28867513459481287, 0.8391463916782738, 0.6717514421272202, 0.4242640687119285, 0.7590721152765897, 0.4242640687119285, 0.6617241025372945, 0.7889320586105297, 0.7058865787567898, 0.6902684899626333, 0.7058865787567898, 0.7912565680749444, 0.8480264949694748, 0.8436614877321074, 0.7505553499465135, 0.7333518105580571, 0.7719753531984982, 0.43033148291193524, 0.8342976876265135, 0.6803091303374612, 0.8666666666666667, 0.3913118960624632, 0.6343350474165466, 0.8391463916782738, 0.2480694691784169, 0.7058865787567897, 0.8573214099741122, 0.722897396012249, 0.5933661039639301, 0.2051956704170308, 0.5449492609130661, 0.828078671210825, 0.7333518105580571, 0.5244044240850757, 0.848528137423857, 0.8333333333333334, 0.5449492609130661, 0.8436614877321074, 0.7759402897989854, 0.7424621202458749, 0.8436614877321074, 0.4879500364742666, 0.44721359549995787, 0.5916079783099616, 0.7999999999999999, 0.35777087639996635, 0.8625819491779427, 0.4743416490252569, 0.8174238913695991, 0.512989176042577, 0.20225995873897262, 0.8436614877321074, 0.7016464154456235, 0.7905694150420948, 0.20225995873897262, 0.5936657514041415, 0.8381163549234938, 0.6900655593423543, 0.6984538909891174, 0.8436614877321074, 0.7807200583588264, 0.8480264949694749, 0.4778895043609751, 0.7348469228349533, 0.8454968154078789, 0.8480264949694749, 0.5449492609130661, 0.6388765649999398, 0.2795084971874737, 0.6527533657682196, 0.8500000000000001, 0.4107919181288746, 0.8198915917499228, 0.828078671210825, 0.7352146220938078, 0.2439750182371333, 0.8436614877321074, 0.32539568672798425, 0.2439750182371333, 0.8436614877321074, 0.39036002917941326, 0.5070925528371099, 0.2795084971874737, 0.5773502691896257, 0.5367450401216933, 0.5936657514041415, 0.8436614877321074, 0.3337119062359573, 0.828078671210825, 0.9190182776172597, 0.5220925637866243, 0.7985957062499248, 0.7999999999999999, 0.2439750182371333, 0.44907311951024925, 0.7912565680749444, 0.7115124735378854, 0.803194840135015, 0.7181324987175317, 0.6984538909891174, 0.5060243137049899, 0.8068715304598786, 0.6390096504226938, 0.4949747468305833, 0.7999999999999999, 0.8090398349558905, 0.7912565680749444, 0.7454993164109748, 0.7912565680749444, 0.32539568672798425, 0.7501937734175208, 0.6024640760767094, 0.2795084971874737, 0.31304951684997057, 0.8480264949694748, 0.8783100656536799, 0.6388765649999398, 0.31304951684997057, 0.7474093186836598, 0.2795084971874737, 0.38729833462074176, 0.32539568672798425, 0.6519202405202648, 0.7889320586105297, 0.7912565680749444, 0.8454968154078789, 0.8221921916437785, 0.7453559924999298, 0.7999999999999999, 0.47434164902525683, 0.7905694150420948, 0.5533985905294664, 0.8454968154078789, 0.23094010767585027, 0.8436614877321074, 0.47434164902525683, 0.7474093186836598, 0.8600131635675318, 0.7912565680749444, 0.2795084971874737, 0.2795084971874737, 0.7889320586105297, 0.7912565680749444, 0.512989176042577, 0.32539568672798425, 0.6984538909891174, 0.579750904364203, 0.8295150620062531, 0.8049844718999242, 0.8333333333333334, 0.6803091303374612, 0.7999999999999999, 0.9391485505499116, 0.6388765649999398, 0.6708203932499369, 0.8480264949694749, 0.803194840135015, 0.32539568672798425, 0.8068715304598786, 0.8666666666666667, 0.15811388300841897, 0.39036002917941326, 0.828078671210825, 0.8198915917499228, 0.28603877677367767, 0.8154100913168028, 0.33806170189140655, 0.87705801930 ...
# similarity_with_index :  [(1.0, 402), (1.0, 0), (0.9838699100999074, 377), (0.9719273929377941, 602), (0.9647638212377322, 536), (0.9647638212377322, 533), (0.9587062360592129, 203), (0.9391485505499116, 184), (0.9237604307034012, 755), (0.9233805168766385, 740), (0.9233805168766385, 730), (0.9209109202723806, 851), (0.9190182776172597, 121), (0.9190182776172596, 852), (0.9190182776172596, 248), (0.9135002783911397, 695), (0.9135002783911397, 417), (0.9135002783911396, 677), (0.9135002783911396, 676), (0.912870929175277, 743), (0.912870929175277, 233), (0.912870929175277, 9), (0.9128709291752769, 337), (0.909154827298409, 393), (0.9091548272984089, 655), (0.9036961141150639, 827), (0.8981462390204985, 421), (0.8981462390204985, 404), (0.8952737857857513, 495), (0.8952737857857513, 494), (0.8874119674649424, 1080), (0.8874119674649424, 880), (0.8858795678282981, 1004), (0.8822575465125694, 720), (0.8822575465125693, 410), (0.8783100656536799, 147), (0.8770580193070292, 199), (0.8730378697119727, 610), (0.8720815992723808, 845), (0.8720815992723808, 774), (0.8720815992723808, 607), (0.8720815992723808, 591), (0.8720815992723808, 582), (0.8720815992723808, 570), (0.8720815992723808, 516), (0.8720815992723808, 502), (0.8720815992723808, 491), (0.8720815992723808, 472), (0.8720815992723808, 468), (0.8720815992723808, 440), (0.8720815992723808, 437), (0.8720815992723808, 430), (0.8720815992723808, 414), (0.8719775384642696, 721), (0.8719775384642695, 741), (0.870571500132014, 223), (0.8696263565463042, 1045), (0.8696263565463042, 1029), (0.8696263565463042, 984), (0.8696263565463042, 972), (0.8696263565463042, 963), (0.8696263565463042, 773), (0.8693182879212227, 724), (0.8693182879212227, 27), (0.8677218312746247, 1082), (0.8672273827165132, 1044), (0.8672273827165132, 964), (0.8672273827165132, 948), (0.8666666666666667, 372), (0.8666666666666667, 191), (0.8666666666666667, 52), (0.8625819491779427, 281), (0.8625819491779427, 269), (0.8625819491779427, 78), (0.8606629658238704, 749), (0.8606629658238704, 706), (0.8600131635675318, 169), (0.8600131635675317, 290), (0.8600131635675317, 279), (0.8600131635675317, 266), (0.8593378488473193, 244), (0.8581163303210331, 849), (0.8581163303210331, 836), (0.8581163303210331, 817), (0.8581163303210331, 795), (0.8581163303210331, 760), (0.8581163303210331, 742), (0.8581163303210331, 723), (0.8573214099741122, 58), (0.8571946154145231, 306), (0.8571946154145231, 219), (0.8571593913749194, 25), (0.8571593913749194, 10), (0.8571593913749193, 832), (0.8524929243380919, 222), (0.8524929243380919, 206), (0.8500000000000001, 102), (0.848528137423857, 805), (0.848528137423857, 432), (0.848528137423857, 66), (0.8480264949694749, 187), (0.8480264949694749, 97), (0.8480264949694749, 93), (0.8480264949694748, 576), (0.8480264949694748, 253), (0.8480264949694748, 204), (0.8480264949694748, 146), (0.8480264949694748, 44), (0.8454968154078789, 164), (0.8454968154078789, 157), (0.8454968154078789, 96), (0.8451542547285165, 912), (0.8451542547285165, 884), (0.8436614877321074, 497), (0.8436614877321074, 443), (0.8436614877321074, 383), (0.8436614877321074, 270), (0.8436614877321074, 228), (0.8436614877321074, 166), (0.8436614877321074, 118), (0.8436614877321074, 111), (0.8436614877321074, 108), (0.8436614877321074, 91), (0.8436614877321074, 83), (0.8436614877321074, 72), (0.8436614877321074, 69), (0.8436614877321074, 45), (0.8436614877321074, 31), (0.8432740427115679, 813), (0.8432740427115679, 474), (0.8427498280790526, 209), (0.8392543274162824, 1074), (0.8392543274162824, 960), (0.8391463916782738, 363), (0.8391463916782738, 55), (0.8391463916782738, 33), (0.8391463916782738, 30), (0.8391463916782738, 24), (0.8391463916782738, 11), (0.8385254915624212, 782), (0.8381163549234939, 674), (0.8381163549234939, 23), (0.8381163549234938, 359), (0.8381163549234938, 280), (0.8381163549234938, 247), (0.8381163549234938, 88), (0.8342976876265135, 653), (0.8342976876265135, 630), (0.8342976876265135, 609), (0.8342976 ...
# result_index :  [402, 0, 377, 602, 536, 533, 203, 184, 755, 740, 730, 851, 121, 852, 248, 695, 417, 677, 676, 743, 233, 9, 337, 393, 655, 827, 421, 404, 495, 494, 1080, 880, 1004, 720, 410, 147, 199, 610, 845, 774, 607, 591, 582, 570, 516, 502, 491, 472, 468, 440, 437, 430, 414, 721, 741, 223, 1045, 1029, 984, 972, 963, 773, 724, 27, 1082, 1044, 964, 948, 372, 191, 52, 281, 269, 78, 749, 706, 169, 290, 279, 266, 244, 849, 836, 817, 795, 760, 742, 723, 58, 306, 219, 25, 10, 832, 222, 206, 102, 805, 432, 66, 187, 97, 93, 576, 253, 204, 146, 44, 164, 157, 96, 912, 884, 497, 443, 383, 270, 228, 166, 118, 111, 108, 91, 83, 72, 69, 45, 31, 813, 474, 209, 1074, 960, 363, 55, 33, 30, 24, 11, 782, 674, 23, 359, 280, 247, 88, 653, 630, 609, 592, 200, 50, 295, 181, 67, 711, 710, 890, 879, 878, 869, 702, 422, 283, 954, 833, 373, 179, 19, 4, 394, 379, 370, 365, 327, 304, 263, 254, 246, 241, 229, 217, 194, 120, 105, 63, 12, 835, 353, 240, 8, 1, 669, 323, 319, 316, 362, 332, 275, 158, 776, 826, 802, 429, 1058, 1018, 944, 386, 378, 361, 286, 284, 243, 234, 195, 104, 21, 18, 22, 461, 358, 262, 80, 299, 197, 1024, 444, 418, 208, 137, 490, 847, 287, 267, 230, 212, 406, 311, 309, 190, 133, 392, 352, 336, 777, 757, 708, 308, 704, 180, 650, 489, 315, 333, 188, 129, 3, 351, 341, 1084, 899, 862, 821, 815, 744, 636, 594, 527, 384, 366, 350, 300, 245, 242, 183, 160, 136, 124, 76, 20, 123, 667, 666, 499, 928, 807, 585, 545, 512, 1079, 1027, 993, 991, 971, 969, 943, 940, 933, 926, 918, 898, 895, 891, 888, 885, 883, 881, 877, 876, 875, 873, 859, 858, 838, 828, 825, 822, 816, 808, 806, 792, 790, 786, 781, 778, 759, 758, 756, 750, 748, 745, 739, 736, 729, 728, 725, 719, 701, 700, 628, 606, 395, 389, 388, 368, 356, 348, 347, 342, 331, 326, 324, 297, 278, 261, 218, 174, 170, 156, 140, 138, 127, 43, 26, 13, 2, 1067, 162, 85, 1076, 1068, 905, 794, 709, 385, 354, 173, 155, 39, 29, 17, 923, 16, 7, 824, 820, 761, 92, 1051, 818, 939, 938, 927, 915, 867, 865, 665, 251, 216, 856, 797, 787, 466, 70, 680, 656, 236, 5, 903, 448, 698, 634, 481, 479, 273, 48, 762, 684, 596, 537, 572, 427, 814, 1065, 1031, 1026, 801, 403, 800, 934, 553, 617, 601, 600, 581, 544, 507, 458, 36, 848, 647, 335, 46, 1001, 842, 142, 627, 168, 150, 979, 515, 139, 159, 799, 71, 397, 727, 307, 854, 221, 106, 95, 322, 310, 64, 47, 409, 250, 505, 920, 765, 737, 258, 703, 973, 965, 957, 937, 935, 931, 930, 921, 919, 914, 906, 896, 887, 401, 528, 360, 224, 59, 860, 646, 518, 506, 130, 696, 543, 416, 1032, 128, 328, 916, 713, 42, 40, 1034, 841, 840, 288, 57, 751, 872, 864, 857, 484, 345, 227, 84, 412, 892, 1066, 255, 375, 334, 302, 301, 211, 201, 177, 131, 90, 642, 1059, 986, 922, 917, 868, 853, 693, 1030, 1008, 982, 981, 967, 932, 925, 641, 567, 556, 551, 529, 41, 15, 231, 89, 259, 605, 420, 953, 793, 770, 566, 552, 405, 639, 559, 554, 550, 182, 51, 623, 436, 834, 34, 1041, 1025, 987, 889, 621, 564, 538, 520, 496, 467, 292, 186, 767, 28, 202, 38, 463, 997, 210, 764, 691, 688, 685, 682, 679, 671, 668, 661, 659, 649, 644, 643, 638, 633, 629, 622, 619, 618, 608, 593, 587, 579, 569, 565, 562, 560, 500, 488, 753, 731, 438, 101, 154, 1075, 893, 796, 956, 949, 583, 534, 313, 998, 950, 317, 260, 257, 225, 134, 672, 555, 546, 524, 492, 477, 451, 431, 424, 390, 381, 380, 349, 340, 325, 321, 293, 185, 148, 99, 367, 1086, 54, 399, 557, 539, 452, 249, 995, 768, 519, 501, 289, 346, 597, 578, 734, 1060, 819, 788, 846, 651, 459, 294, 975, 681, 658, 615, 265, 604, 530, 276, 486, 779, 763, 863, 143, 413, 487, 707, 810, 712, 694, 660, 588, 561, 355, 568, 1021, 994, 498, 904, 769, 648, 624, 396, 117, 87, 475, 60, 75, 683, 415, 722, 344, 548, 870, 812, 738, 178, 952, 716, 115, 1020, 726, 14, 6, 613, 1064, 1023, 897, 690, 590, 589, 493, 735, 511, 780, 426, 913, 163, 664, 637, 1006, 675, 508, 580, 510, 482, 476, 471, 462, 453, 446, 98, 68, 62, 312, 850, 772, 771, 747, 1033, 686, 645, 575, 457, 1022, 733, 705, 942, 632, 631, 116, 523, 371, 894, 574, 285, 65, 329, 122, 542, 514, 483, 673, 460, 526, 663, 689, 455, 882, 809, 175, ...
# [402, 0, 377, 602, 536, 533, 203, 184, 755, 740, 730]
# 402    CNTS_000000000022470
# 0      CONT_000000000500281
# 377    CNTS_000000000021894
# 602    CNTS_200000000010341
# 536    CNTS_000000000019215
# 533    CONT_000000000500362
# 203    CNTS_000000000018441
# 184    CNTS_000000000020676
# 755    CNTS_000000000021055
# 740    CNTS_000000000021207
# 730    CNTS_000000000021411
# Name: id, dtype: object

# %%
list(recommend.values)
# Out:
# ['CNTS_000000000022470',
#  'CONT_000000000500281',
#  'CNTS_000000000021894',
#  'CNTS_200000000010341',
#  'CNTS_000000000019215',
#  'CONT_000000000500362',
#  'CNTS_000000000018441',
#  'CNTS_000000000020676',
#  'CNTS_000000000021055',
#  'CNTS_000000000021207',
#  'CNTS_000000000021411']
