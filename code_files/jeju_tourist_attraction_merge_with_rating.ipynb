# %%
import pandas as pd

# %%
dir_path = "/content/drive/MyDrive/추천시스템 입문반/data/ml-latest-small"
api_file_path = dir_path + '/jeju_tourist_attractions.csv'
more_info_file_path = dir_path + '/jeju_tourist_attraction_more_info.csv'
file1 = pd.read_csv(api_file_path)
file2 = pd.read_csv(more_info_file_path,encoding='cp949')

# %%
file1.head(2)
# Out:
#    Unnamed: 0                                         alltag  \
# 0           0                                        꽃축제, 봄꽃
# 1           1  꽃, 꽃집, 원데이클래스, 쇼핑,기념품/소품,꽃다발, 웨딩부케, 야외촬영부케,가능
#
#              contentsid          title                    address  \
# 0  CNTS_200000000013186  제주허브동산 설유화 축제  제주특별자치도 서귀포시 표선면 표선리 2608
# 1  CNTS_200000000007112         프레쉬모먼트    제주특별자치도 제주시 아라1동 6119-2
#
#                  roadaddress                         tag  \
# 0  제주특별자치도 서귀포시 표선면 돈오름로 170        꽃축제,봄꽃,힐링,포토스팟,행사,축제
# 1         제주특별자치도 제주시 인다2길 8  꽃,꽃집,원데이클래스,쇼핑,관광기념품,상점/상가
#
#                                         introduction   latitude   longitude  \
# 0                허브동산의 봄을 알리는 첫 꽃인 설유화를 만날 수 있는 꽃 축제  33.329850  126.814854
# 1  차근차근 사진 찍을 장소와 의상까지 마련해 놓았다면, 예비 신혼부부가 함께 웨딩부케...  33.467295  126.545115
#
#    ... region2cd.value region2cd.label region2cd.refId repPhoto.descseo  \
# 0  ...            26.0              표선      region2>26   제주 허브동산 설유화 축제
# ...

# %%
file2.head()
# Out:
#                   콘텐츠ID 콘텐츠분류      제목  언어  타이틀SEO 연관콘텐츠   평점  \
# 0  CNTS_000000000021903    숙박    해피펜션  국문    해피펜션   NaN  NaN
# 1  CONT_000000000501391   음식점  탐라 뚝배기  국문  탐라 뚝배기   NaN  NaN
# 2  CONT_000000000501399   음식점     토담골  국문     토담골   NaN  NaN
# 3  CNTS_000000000018301   음식점    우유부단  국문    우유부단   NaN  5.0
# 4  CNTS_000000000020277   관광지     공천포  국문     공천포   NaN  4.0
#
#                    소셜네트워크URL    조회수 외부검색어  ...  번체공개여부  말레이어공개여부  번체모바일사용여부  \
# 0  blog.naver.com/happycho25    759   NaN  ...     NaN       NaN        NaN
# 1                        NaN   2569   NaN  ...       y       NaN          y
# 2                        NaN   1452   NaN  ...       y       NaN          y
# 3                        NaN  19738   NaN  ...       n       NaN          y
# 4                        NaN   3850   NaN  ...     NaN       NaN        NaN
#
#    말어모바일사용여부     번체승인일시 말레이어승인일시   번체번역요청일시  말레이어번역요청일시  번체SEO자동여부  \
# 0        NaN        NaN      NaN        NaN         NaN        NaN
# ...

# %%
tourist_rating = file2.loc[:,['콘텐츠ID','인기점수']]
print(tourist_rating.shape)
tourist_rating.rename(columns={'콘텐츠ID':'contentsid'},inplace=True)
tourist_rating.head(3)
# Out:
# (5780, 2)
#              contentsid    인기점수
# 0  CNTS_000000000021903  1518.0
# 1  CONT_000000000501391  5138.0
# 2  CONT_000000000501399  2904.0

# %%
merge_file = pd.merge(left=file1,right=tourist_rating,on='contentsid',how='inner')

# %%
merge_file.head()
# Out:
#    Unnamed: 0                                             alltag  \
# 0           1      꽃, 꽃집, 원데이클래스, 쇼핑,기념품/소품,꽃다발, 웨딩부케, 야외촬영부케,가능
# 1           2                                               액티비티
# 2           3                                                 펜션
# 3           4    추자야식,추자도야식,추자식당,추자음식점,추자도,무료 WIFI,화장실,카드결제,현금결제
# 4           6  정식,두루치기,매운탕,찜,한식,현금결제,카드결제,화장실,음료대,유도 및 안내시설,경...
#
#              contentsid                  title                    address  \
# 0  CNTS_200000000007112                 프레쉬모먼트    제주특별자치도 제주시 아라1동 6119-2
# 1  CNTS_200000000013167  2022 하영올레 걷기축제 & 걷기주간     제주특별자치도 서귀포시 서홍동 440-1
# 2  CNTS_000000000019278                  리버풀펜션       제주특별자치도 제주시 도두봉6길 13
# 3  CNTS_200000000009125                   마마식당  제주특별자치도 제주시 추자면 대서리 140-6
# 4  CONT_000000000501227                  마라톤식당    제주특별자치도 제주시 오라일동 2441-1
#
#               roadaddress                                            tag  \
# ...

# %%
tmp = file1.append(merge_file)
tmp = tmp.drop_duplicates(subset=['contentsid'],keep=False)
tmp.head(4)
# Out:
#     Unnamed: 0                                  alltag            contentsid  \
# 0            0                                 꽃축제, 봄꽃  CNTS_200000000013186
# 5            5                                축제, 문화관광  CNTS_200000000013168
# 29          29  축제,웰니스,행사,체험,자연학습장,자연휴양림,숲,생태숲,캠핑,포토스팟  CNTS_200000000013419
# 59          59                                      축제  CNTS_200000000013424
#
#                              title                      address  \
# 0                    제주허브동산 설유화 축제    제주특별자치도 서귀포시 표선면 표선리 2608
# 5   세계자동차&피아노박물관 4th 봄날의 향연 뮤지엄콘서트  제주특별자치도 서귀포시 안덕면 상창리 2065-4
# 29     한개의 별을 노래하자(제2회 웰니스 숲힐링 축제)         제주특별자치도 서귀포시 호근동 산 1
# 59                 2022 서귀포 봄맞이 축제       제주특별자치도 서귀포시 서귀동 512-1
#
#                     roadaddress                                     tag  \
# 0     제주특별자치도 서귀포시 표선면 돈오름로 170                    꽃축제,봄꽃,힐링,포토스팟,행사,축제
# 5   제주특별자치도 서귀포시 안덕면 중산간서로 1610                    축제,문화관광,행사,박물관,실내관광지
# ...

# %%
tmp.loc[:,['title','contentscd.label']]
# Out:
#                                                   title contentscd.label
# 0                                         제주허브동산 설유화 축제            축제/행사
# 5                        세계자동차&피아노박물관 4th 봄날의 향연 뮤지엄콘서트            축제/행사
# 29                          한개의 별을 노래하자(제2회 웰니스 숲힐링 축제)            축제/행사
# 59                                      2022 서귀포 봄맞이 축제            축제/행사
# 76    PRESENT OF JEJU, 스누피가든 5월 EVENT - GROWING IN S...            축제/행사
# ...                                                 ...              ...
# 4159                                              해성도뚜리              음식점
# 4227      2022년 여름 놓치지 말아야 할 제주 관광 10선 <다시! 제주 여름에 빠지다>             테마여행
# 4328                      [안심채움×맛있는 제주만들기] 제주 남부(서귀포시)편             테마여행
# 4335                    제2회 웰니스 숲힐링 축제 - 숲, 내일의 우리를 만나다            축제/행사
# 4354                            [안심채움×맛있는 제주만들기] 제주 동부편             테마여행
#
# [93 rows x 2 columns]

# %%
merge_file.to_csv(dir_path+'/toursit_attraction_with_rating.csv')
tmp.to_csv(dir_path+'/toursit_attraction_with_rating_removed.csv')

# %%
dir_path = "/content/drive/MyDrive/추천시스템 입문반/data/ml-latest-small"
file_path = dir_path + '/toursit_attraction_with_rating.csv'
tmp_file = pd.read_csv(file_path)
tmp_file.head(4)
# Out:
#    Unnamed: 0  Unnamed: 0.1                                           alltag  \
# 0           0             1    꽃, 꽃집, 원데이클래스, 쇼핑,기념품/소품,꽃다발, 웨딩부케, 야외촬영부케,가능
# 1           1             2                                             액티비티
# 2           2             3                                               펜션
# 3           3             4  추자야식,추자도야식,추자식당,추자음식점,추자도,무료 WIFI,화장실,카드결제,현금결제
#
#              contentsid                  title                    address  \
# 0  CNTS_200000000007112                 프레쉬모먼트    제주특별자치도 제주시 아라1동 6119-2
# 1  CNTS_200000000013167  2022 하영올레 걷기축제 & 걷기주간     제주특별자치도 서귀포시 서홍동 440-1
# 2  CNTS_000000000019278                  리버풀펜션       제주특별자치도 제주시 도두봉6길 13
# 3  CNTS_200000000009125                   마마식당  제주특별자치도 제주시 추자면 대서리 140-6
#
#               roadaddress                                            tag  \
# 0      제주특별자치도 제주시 인다2길 8                     꽃,꽃집,원데이클래스,쇼핑,관광기념품,상점/상가
# ...

# %%
sorted_file = tmp_file.sort_values(by='인기점수',ascending=False)
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 4162        4162            46
# 4074        4074            55
# 4259        4259            45
# 4243        4243            27
# 3896        3896            74
# 4266        4266            53
# 3904        3904            82
# 3865        3865            43
# 4038        4038            19
# 4056        4056            37
#
#                                                  alltag            contentsid  \
# 4162      숲길,걷기/등산,친구,커플,흐림,봄,자연경관,도보여행,도보,숲,단풍,화장실,어려움  CONT_000000000500281
# 4074  섬속의섬,경관/포토,아이,맑음,자연경관,포토스팟,어린이,봄꽃,유채꽃,유네스코,공용주...  CONT_000000000500477
# 4259  일출,오름,경관/포토,부모,자연경관,포토스팟,유네스코,공용주차장,현금결제,카드결제,...  CONT_000000000500349
# 4243  걷기/등산,아이,흐림,여름,힐링,자연경관,어린이,수국,공용주차장,현금결제,카드결제,...  CONT_000000000500270
# 3896  폭포, 밤, 경관/포토, 부모, 맑음, 여름,공용주차장,현금결제,카드결제,화장실,음...  CONT_000000000500618
# 4266  동굴,경관/포토,아이,흐림,여름,자연경관,포토스팟,어린이,유네스코,공용주차장,현금결...  CONT_000000000500182
# ...

# %%
sorted_file.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'alltag', 'contentsid', 'title',
#        'address', 'roadaddress', 'tag', 'introduction', 'latitude',
#        'longitude', 'postcode', 'phoneno', 'contentscd.value',
#        'contentscd.label', 'contentscd.refId', 'region1cd.value',
#        'region1cd.label', 'region1cd.refId', 'region2cd.value',
#        'region2cd.label', 'region2cd.refId', 'repPhoto.descseo',
#        'repPhoto.photoid.photoid', 'repPhoto.photoid.imgpath',
#        'repPhoto.photoid.thumbnailpath', 'region1cd', 'region2cd', 'repPhoto',
#        '인기점수'],
#       dtype='object')

# %%
sorted_file.loc[sorted_file['contentscd.label']=='관광지']
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 4162        4162            46
# 4074        4074            55
# 4259        4259            45
# 4243        4243            27
# 3896        3896            74
# ...          ...           ...
# 3683        3683            58
# 2033        2033            79
# 3751        3751            26
# 2546        2546            96
# 3779        3779            54
#
#                                                  alltag            contentsid  \
# 4162      숲길,걷기/등산,친구,커플,흐림,봄,자연경관,도보여행,도보,숲,단풍,화장실,어려움  CONT_000000000500281
# 4074  섬속의섬,경관/포토,아이,맑음,자연경관,포토스팟,어린이,봄꽃,유채꽃,유네스코,공용주...  CONT_000000000500477
# 4259  일출,오름,경관/포토,부모,자연경관,포토스팟,유네스코,공용주차장,현금결제,카드결제,...  CONT_000000000500349
# 4243  걷기/등산,아이,흐림,여름,힐링,자연경관,어린이,수국,공용주차장,현금결제,카드결제,...  CONT_000000000500270
# 3896  폭포, 밤, 경관/포토, 부모, 맑음, 여름,공용주차장,현금결제,카드결제,화장실,음...  CONT_000000000500618
# ...                                                 ...                   ...
# ...

# %%
sorted_only_attraction = sorted_file.loc[sorted_file['contentscd.label']=='관광지']

# %%
tmp = tmp.loc[tmp['contentscd.label']=='관광지']
tmp
# Out:
#       Unnamed: 0                                             alltag  \
# 1260          60  1,공용주차장,현금결제,카드결제,화장실,무료 WIFI,카드결제,현금결제,,,어려움,...
# 1647          47  요가,웰니스,공용주차장,카드결제,화장실,무료 WIFI,카드결제,네이버페이, 카카오페...
# 1814          14  힐링,공용주차장,현금결제,카드결제,화장실,무료 WIFI,카드결제,현금결제,,영어,,...
# 1921          21                                              문화유적지
# 4049          49                                    휴식/힐링,카드결제,현금결제
#
#                 contentsid   title                     address  \
# 1260  CNTS_200000000013506      해빛  제주특별자치도 제주시 조천읍 신촌리 1899-1
# 1647  CNTS_200000000013306     빠우사   제주특별자치도 제주시 조천읍 선흘리 472-5
# 1814  CNTS_200000000013530   요가느림원       제주특별자치도 제주시 노형동 922-6
# 1921  CNTS_000000000019091   묵리처녀당    제주특별자치도 제주시 추자면 묵리 229-1
# 4049  CNTS_200000000013247  제주양떼목장     제주특별자치도 제주시 애월읍 납읍리 114
#
#                       roadaddress                          tag  \
# 1260       제주특별자치도 제주시 조천읍 신촌9길 8              기념품,상점/상가,체험,힐링
# ...

# %% [markdown]
# #인기점수가 있는 관광지와 인기점수가 없는 관광지 하나로 합치기

# %%
test = sorted_only_attraction.append(tmp)
test
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 4162        4162          46.0
# 4074        4074          55.0
# 4259        4259          45.0
# 4243        4243          27.0
# 3896        3896          74.0
# ...          ...           ...
# 1260          60           NaN
# 1647          47           NaN
# 1814          14           NaN
# 1921          21           NaN
# 4049          49           NaN
#
#                                                  alltag            contentsid  \
# 4162      숲길,걷기/등산,친구,커플,흐림,봄,자연경관,도보여행,도보,숲,단풍,화장실,어려움  CONT_000000000500281
# 4074  섬속의섬,경관/포토,아이,맑음,자연경관,포토스팟,어린이,봄꽃,유채꽃,유네스코,공용주...  CONT_000000000500477
# 4259  일출,오름,경관/포토,부모,자연경관,포토스팟,유네스코,공용주차장,현금결제,카드결제,...  CONT_000000000500349
# 4243  걷기/등산,아이,흐림,여름,힐링,자연경관,어린이,수국,공용주차장,현금결제,카드결제,...  CONT_000000000500270
# 3896  폭포, 밤, 경관/포토, 부모, 맑음, 여름,공용주차장,현금결제,카드결제,화장실,음...  CONT_000000000500618
# ...                                                 ...                   ...
# ...

# %%
test[test['인기점수'].isnull()]
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 3779        3779          54.0
# 1260          60           NaN
# 1647          47           NaN
# 1814          14           NaN
# 1921          21           NaN
# 4049          49           NaN
#
#                                                  alltag            contentsid  \
# 3779  박물관, 밀랍인형,공용주차장,화장실,무료 WIFI,경보 및 피난시설,카드결제,현금결...  CNTS_200000000012946
# 1260  1,공용주차장,현금결제,카드결제,화장실,무료 WIFI,카드결제,현금결제,,,어려움,...  CNTS_200000000013506
# 1647  요가,웰니스,공용주차장,카드결제,화장실,무료 WIFI,카드결제,네이버페이, 카카오페...  CNTS_200000000013306
# 1814  힐링,공용주차장,현금결제,카드결제,화장실,무료 WIFI,카드결제,현금결제,,영어,,...  CNTS_200000000013530
# 1921                                              문화유적지  CNTS_000000000019091
# 4049                                    휴식/힐링,카드결제,현금결제  CNTS_200000000013247
#
#           title                     address                  roadaddress  \
# 3779  무비랜드왁스뮤지엄       제주특별자치도 서귀포시 중문동 2565       제주특별자치도 서귀포시 중문관광로 205
# ...

# %%
test['인기점수'] = test['인기점수'].fillna(0)

# %%
test.drop(['Unnamed: 0','Unnamed: 0.1','region1cd','region2cd','repPhoto'],axis=1,inplace=True)

# %%
test.reset_index(drop=True,inplace=True)

# %%
test
# Out:
#                                                  alltag            contentsid  \
# 0         숲길,걷기/등산,친구,커플,흐림,봄,자연경관,도보여행,도보,숲,단풍,화장실,어려움  CONT_000000000500281
# 1     섬속의섬,경관/포토,아이,맑음,자연경관,포토스팟,어린이,봄꽃,유채꽃,유네스코,공용주...  CONT_000000000500477
# 2     일출,오름,경관/포토,부모,자연경관,포토스팟,유네스코,공용주차장,현금결제,카드결제,...  CONT_000000000500349
# 3     걷기/등산,아이,흐림,여름,힐링,자연경관,어린이,수국,공용주차장,현금결제,카드결제,...  CONT_000000000500270
# 4     폭포, 밤, 경관/포토, 부모, 맑음, 여름,공용주차장,현금결제,카드결제,화장실,음...  CONT_000000000500618
# ...                                                 ...                   ...
# 1093  1,공용주차장,현금결제,카드결제,화장실,무료 WIFI,카드결제,현금결제,,,어려움,...  CNTS_200000000013506
# 1094  요가,웰니스,공용주차장,카드결제,화장실,무료 WIFI,카드결제,네이버페이, 카카오페...  CNTS_200000000013306
# 1095  힐링,공용주차장,현금결제,카드결제,화장실,무료 WIFI,카드결제,현금결제,,영어,,...  CNTS_200000000013530
# 1096                                              문화유적지  CNTS_000000000019091
# 1097                                    휴식/힐링,카드결제,현금결제  CNTS_200000000013247
#
# ...

# %%
test.to_csv(dir_path+'/only_attraction_db.csv',encoding = 'utf-8')

# %%
test.head(1)
# Out:
#                                           alltag            contentsid  title  \
# 0  숲길,걷기/등산,친구,커플,흐림,봄,자연경관,도보여행,도보,숲,단풍,화장실,어려움  CONT_000000000500281  사려니숲길
#
#                        address                  roadaddress  \
# 0  제주특별자치도 제주시 조천읍 교래리 산 137-1  제주특별자치도 제주시 조천읍 교래리 산 137-1
#
#                                      tag  \
# 0  숲길,걷기/등산,친구,커플,흐림,봄,자연경관,도보여행,도보,숲,단풍
#
#                               introduction  latitude  longitude postcode  ...  \
# 0  제주 숨은 비경 31, 삼나무 향기에 취하며 걷는 아름답고 청정한 숲길  33.40845  126.63976      NaN  ...
#
#   region1cd.label region1cd.refId region2cd.value region2cd.label  \
# 0             제주시  region>region1            15.0              조천
#
#   region2cd.refId      repPhoto.descseo repPhoto.photoid.photoid  \
# 0      region1>15  Saryeoni Forest Path                  18168.0
#
#                             repPhoto.photoid.imgpath  \
# 0  https://api.cdn.visitjeju.net/photomng/imgpath...
#
# ...
