# %%
# !pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install cairosvg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 45 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 69 kB 2.0 MB/s
# ...
#   Created wheel for cairocffi: filename=cairocffi-1.4.0-py3-none-any.whl size=88775 sha256=8588619eea6ad70d4ff1ef93ee878533685bba053e14aa5807950f7fa740ae3c
#   Stored in directory: /root/.cache/pip/wheels/7a/2b/da/aec872f95d2c24105496ef149a9a576f52daf686f8f2127541
# Successfully built cairocffi
# ...

# %%
from PIL import Image
import cairosvg

# %%
dir_path = "/content/drive/MyDrive/pillow_image_files"
img1 = Image.open(dir_path+"/쵸단1.png")
img2 = Image.open(dir_path+"/츄정1.png")
img3_path = dir_path+'/markerDay1.svg'

# %%
from io import BytesIO

# %%
out = BytesIO()
cairosvg.svg2png(url = img3_path,write_to=out)
image_ = Image.open(out)
display(image_)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=426x509 at 0x7F9B080BF850>

# %%
from IPython.display import Image

# %%
display(img1)
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=703x492 at 0x7F725E6B6110>

# %%
img1 = img1.resize((450,163))
img2 = img2.resize((450,163))
img1_size = img1.size
img2_size = img2.size

# %%
img1_size
# Out:
# (450, 163)

# %%
new_img = Image.new('RGB',(img1_size[0], 2 * img1_size[1]),(250,250,250))
new_img.paste(img1,(0,0))
new_img.paste(img2,(0,img1_size[1]))

# %%
display(new_img)
# Out:
# <PIL.Image.Image image mode=RGB size=450x326 at 0x7F7253C7BA90>

# %%
frame = Image.open("/content/drive/MyDrive/pillow_image_files/프레임사진.jpeg")

# %%
resize_img1 = img1.resize((260,340))
frame.paste(resize_img1,(30,110))
display(frame)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=620x920 at 0x7F7253C52B50>

# %%
frame.paste(resize_img1,(325,110))
display(frame)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=620x920 at 0x7F7253C52B50>
