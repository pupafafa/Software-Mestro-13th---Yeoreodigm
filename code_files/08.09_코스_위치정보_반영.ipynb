# %% [markdown]
# ##필요한 라이브러리 및 함수 로드

# %%
import json
import pandas as pd
import psycopg2
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm

# %%
def load_db():
  with open("/content/drive/MyDrive/yeoreodigm/data_files/db_info.json") as json_file:
    DB_INFO = json.load(json_file)
  
  endpoint = DB_INFO["ENDPOINT"]
  dbname = DB_INFO["DB_NAME"]
  user = DB_INFO["USER_ID"]
  password = DB_INFO["PASSWORD"]
  db = psycopg2.connect(host=endpoint,dbname=dbname,user=user,password=password)
  return db

# %%
def load_entire_place(db):
  cursor= db.cursor()
  df = pd.DataFrame()
  
  load_place_sql= (f"SELECT place_id, region2 FROM places_analysis")
  
  cursor.execute(load_place_sql)
  result = cursor.fetchall()
  df = pd.DataFrame(result)
  df.columns = ['id','region2']

  return df

# %%
def load_entire_course(db):
  cursor= db.cursor()
  df = pd.DataFrame()
  
  load_course_sql= (f"SELECT id, places FROM course_ ")

  cursor.execute(load_course_sql)
  result = cursor.fetchall()
  df = pd.DataFrame(result)
  df.columns = ['id','places']

  return df

# %% [markdown]
# ##location 정의 및 적용

# %%
east = ['구좌','성산','표선','우도']
west = ['안덕','대정','한경','한림','추자도','가파도','마라도','비양도','차귀도']
north = ['제주시내','애월','조천']
south = ['서귀포시내','남원','중문']

# %%
db = load_db()
course = load_entire_course(db)

# %%
course.head(3)
# Out:
#    id                         places
# 0   1              [602, 10, 58, 29]
# 1   2  [19, 37, 10, 602, 60, 58, 29]
# 2   3          [19, 602, 10, 58, 29]

# %%
place = load_entire_place(db)

# %%
place.head(4)
# Out:
#     id region2
# 0  204     추자도
# 1  542     추자도
# 2  591     추자도
# 3  592     추자도

# %%
sample_course = [19, 37, 10, 602, 60, 58, 29]

# %%
location_template = [east,west,south,north]

# %%
location_template
# Out:
# [['구좌', '성산', '표선', '우도'],
#  ['안덕', '대정', '한경', '한림', '추자도', '가파도', '마라도', '비양도', '차귀도'],
#  ['서귀포시내', '남원', '중문'],
#  ['제주시내', '애월', '조천']]

# %%
for crs in course['places']:
  print(crs)
  break
# Out:
# [602, 10, 58, 29]

# %% [markdown]
# ##여행지 위치정보 로드

# %%
entire_direction_point = []
for crs in tqdm(course['places']):
  direction_point = np.zeros(4)
  for location in crs:
    region = place.loc[place['id']==location,'region2'].values[0]
    #region_list.append(region)
    for i in range(4):
      if region in location_template[i]:
        direction_point[i] += 1
  entire_direction_point.append(direction_point)
# Out:
# 100%|██████████| 3811/3811 [00:20<00:00, 181.63it/s]

# %%
direction_df = pd.DataFrame(entire_direction_point)
direction_df.columns = ['east','west','south','north']

# %% [markdown]
# ##코스에 위치정보 반영

# %%
tmp_np = np.array([1,4,2,0])
max_idx = tmp_np.argmax()
percentage = tmp_np[max_idx]/tmp_np.sum()
tmptest = f'{percentage : 0.2f}'
print(tmptest)
print(type(tmptest))
# Out:
#  0.57
# <class 'str'>

# %%
save_max_location = []
for crs in entire_direction_point:
  max_idx = crs.argmax()
  max_ratio = crs[max_idx] / crs.sum()
  if max_ratio > 0.5:
    if max_idx == 0:
      save_max_location.append("East")
    elif max_idx==1:
      save_max_location.append("West")
    elif max_idx==2:
      save_max_location.append("South")
    else:
      save_max_location.append("North")
  else:
    save_max_location.append("Mixed")
  #max_ratio = f"{max_ratio:.2f}"
  #print(crs, max_ratio,max_idx,save_max_location[cnt])

# %%
save_max_location[:20]
# Out:
# ['Mixed',
#  'Mixed',
#  'Mixed',
#  'North',
#  'Mixed',
#  'Mixed',
#  'Mixed',
#  'Mixed',
#  'West',
#  'East',
#  'West',
#  'East',
#  'Mixed',
#  'Mixed',
#  'Mixed',
#  'Mixed',
#  'Mixed',
#  'North',
#  'Mixed',
#  'Mixed']

# %%
course['main_location'] = save_max_location

# %%
course
# Out:
#         id                                             places main_location
# 0        1                                  [602, 10, 58, 29]         Mixed
# 1        2                      [19, 37, 10, 602, 60, 58, 29]         Mixed
# 2        3                              [19, 602, 10, 58, 29]         Mixed
# 3        4                                      [37, 202, 58]         North
# 4        5                              [37, 60, 202, 58, 29]         Mixed
# ...    ...                                                ...           ...
# 3806  3807           [59, 8, 5, 3, 439, 6, 22, 10, 24, 15, 9]         Mixed
# 3807  3808  [37, 144, 8, 78, 456, 66, 62, 49, 162, 5, 88, ...         Mixed
# 3808  3809               [18, 15, 87, 29, 9, 5, 179, 112, 61]         South
# 3809  3810                     [22, 62, 5, 75, 284, 142, 172]         Mixed
# 3810  3811  [37, 103, 192, 439, 13, 6, 4, 140, 310, 134, 3...          East
#
# [3811 rows x 3 columns]

# %%
direction_df
# Out:
#       east  west  south  north
# 0      2.0   1.0    0.0    1.0
# 1      2.0   2.0    0.0    3.0
# 2      2.0   1.0    0.0    2.0
# 3      1.0   0.0    0.0    2.0
# 4      2.0   1.0    0.0    2.0
# ...    ...   ...    ...    ...
# 3806   4.0   4.0    2.0    1.0
# 3807   5.0   3.0    6.0    4.0
# 3808   2.0   1.0    5.0    1.0
# 3809   0.0   3.0    2.0    2.0
# 3810  11.0   1.0    0.0    9.0
#
# [3811 rows x 4 columns]

# %%
joined_course = course.join(direction_df)
joined_course
# Out:
#         id                                             places main_location  \
# 0        1                                  [602, 10, 58, 29]         Mixed
# 1        2                      [19, 37, 10, 602, 60, 58, 29]         Mixed
# 2        3                              [19, 602, 10, 58, 29]         Mixed
# 3        4                                      [37, 202, 58]         North
# 4        5                              [37, 60, 202, 58, 29]         Mixed
# ...    ...                                                ...           ...
# 3806  3807           [59, 8, 5, 3, 439, 6, 22, 10, 24, 15, 9]         Mixed
# 3807  3808  [37, 144, 8, 78, 456, 66, 62, 49, 162, 5, 88, ...         Mixed
# 3808  3809               [18, 15, 87, 29, 9, 5, 179, 112, 61]         South
# 3809  3810                     [22, 62, 5, 75, 284, 142, 172]         Mixed
# 3810  3811  [37, 103, 192, 439, 13, 6, 4, 140, 310, 134, 3...          East
#
#       east  west  south  north
# 0      2.0   1.0    0.0    1.0
# 1      2.0   2.0    0.0    3.0
# 2      2.0   1.0    0.0    2.0
# 3      1.0   0.0    0.0    2.0
# 4      2.0   1.0    0.0    2.0
# ...    ...   ...    ...    ...
# 3806   4.0   4.0    2.0    1.0
# 3807   5.0   3.0    6.0    4.0
# 3808   2.0   1.0    5.0    1.0
# 3809   0.0   3.0    2.0    2.0
# 3810  11.0   1.0    0.0    9.0
#
# [3811 rows x 7 columns]

# %% [markdown]
# ###최종 결과본

# %%
joined_course[['id','places','east','west','south','north','main_location']]
# Out:
#         id                                             places  east  west  \
# 0        1                                  [602, 10, 58, 29]   2.0   1.0
# 1        2                      [19, 37, 10, 602, 60, 58, 29]   2.0   2.0
# 2        3                              [19, 602, 10, 58, 29]   2.0   1.0
# 3        4                                      [37, 202, 58]   1.0   0.0
# 4        5                              [37, 60, 202, 58, 29]   2.0   1.0
# ...    ...                                                ...   ...   ...
# 3806  3807           [59, 8, 5, 3, 439, 6, 22, 10, 24, 15, 9]   4.0   4.0
# 3807  3808  [37, 144, 8, 78, 456, 66, 62, 49, 162, 5, 88, ...   5.0   3.0
# 3808  3809               [18, 15, 87, 29, 9, 5, 179, 112, 61]   2.0   1.0
# 3809  3810                     [22, 62, 5, 75, 284, 142, 172]   0.0   3.0
# 3810  3811  [37, 103, 192, 439, 13, 6, 4, 140, 310, 134, 3...  11.0   1.0
#
#       south  north main_location
# 0       0.0    1.0         Mixed
# 1       0.0    3.0         Mixed
# 2       0.0    2.0         Mixed
# 3       0.0    2.0         North
# 4       0.0    2.0         Mixed
# ...     ...    ...           ...
# 3806    2.0    1.0         Mixed
# 3807    6.0    4.0         Mixed
# 3808    5.0    1.0         South
# 3809    2.0    2.0         Mixed
# 3810    0.0    9.0          East
#
# [3811 rows x 7 columns]

# %%
joined_course = joined_course[['id','east','west','south','north','main_location']]

# %% [markdown]
# ##Db에 적용

# %%
for info in joined_course.values:
  id=info[0]
  east = info[1]
  west = info[2]
  south = info[3]
  north = info[4]
  main_location = info[5]
  for i in info:
    print(i)
  break
#sql = f"update table course_ set east={east},west={west},south={south},'north={north},main_location={main_location} where id = {id}"
# Out:
# 1
# 2.0
# 1.0
# 0.0
# 1.0
# Mixed

# %% [markdown]
# ##sample 뽑아서 확인 - id : 115번, 봄을 찾아 떠나는 제주도 동쪽여행 3박 4일 - 테스트

# %%
tttt = np.zeros(4)
for i in [8,13,4,26,145,3,3,52]:
  print(place.loc[place['id']==i,'region2'].values[0])
  for j in range(4):
    if place.loc[place['id']==i,'region2'].values[0] in location_template[j]:
      tttt[j] += 1
# Out:
# 한림
# 구좌
# 구좌
# 구좌
# 성산
# 성산
# 성산
# 성산

# %%
tttt
# Out:
# array([7., 1., 0., 0.])

# %% [markdown]
# ##추천 메소드에 인자로 받기

# %%
str1 = "North,East"
str1.split(",")
# Out:
# ['North', 'East']

# %%
direction_list = ['North','East']
num_of_direction = len(direction_list) 
#기존 sql where 절 내에 location_sql 정보 추가하자


#case 1 : 모든 지역 선택했거나 아무지역도 선택안하면 -> 전지역 
if num_of_direction == 4 or num_of_direction == 0:
  location_sql = 'and 1=1'
#case 2 : 한 지역만 선택한 경우 
elif num_of_direction == 1:
  direction = direction_list[0]
  location_sql = f"and main_location = {direction}"
#case 3 : 여러 지역을 선택한 경우
else:
  if num_of_direction == 2:
    location_sql = f"and main_location = Mix and {direction_list[0]} >0 and {direction_list[1]} >0"
  elif num_of_direction == 3:
    location_sql = f"and main_location = Mix and {direction_list[0]} >0 and {direction_list[1]} >0 and {direction_list[2]} >0"

# %%
sql = "select * from course_"
cursor = db.cursor()
cursor.execute(sql)
result = cursor.fetchall()
print(result)
# Out:
# [(1, '[청주출발]연합패키지 제주를 반하다 3일_관광호텔 화순곶자왈+서커스+석예원한방족욕+아쿠아플라넷', [602, 10, 58, 29], 1.25, 2.0, 1.25, 1.25, 2.75, 1.0, 1.75, 0.25, 3, 4), (2, '[청주출발]연합패키지 노팁/노옵션 제주 3일_관광호텔 산방산유람선+ 화순곶자왈+서커스+아쿠아플라넷+오션아레나', [19, 37, 10, 602, 60, 58, 29], 1.7142857142857142, 2.4285714285714284, 1.2857142857142858, 1.4285714285714286, 2.571428571428572, 0.5714285714285714, 2.2857142857142856, 0.4285714285714285, 3, 7), (3, '[부산출발_※3일차 석식 전복죽포함※]연합패키지 제주를 반하다 3일_관광호텔 화순곶자왈+서커스+석예원한방족욕+아쿠아플라넷', [19, 602, 10, 58, 29], 1.4, 2.2, 1.2, 1.4, 2.8, 0.8, 2.0, 0.2, 3, 5), (4, '[청주출발]"모두 알뜰 패키지" 제주 관광호텔 2박3일 비밀의 그림자+ 웰빙 족욕', [37, 202, 58], 2.0, 3.0, 1.6666666666666667, 1.6666666666666667, 1.6666666666666667, 1.0, 3.0, 0.6666666666666666, 6, 3), (5, '[청주출발]◈감귤타르트증정/코시롱한나들이◈아쿠아플라넷+유람선-제주 로베로관광호텔 2박3일 산방산유람선+아쿠아플라넷', [37, 60, 202, 58, 29], 1.6, 2.4, 1.6, 1.4, 2.0, 0.8, 2.8, 0.6, 3, 5), (6, '[청주출발]◈감귤타르트증정/名品 효도◈고품격 노팁 노옵션-제주 로베로관광호텔 2박3일 해저잠수함+워터서커스+전일정식사포함', [37, 10, 65, 118, 58, 9], 2.5, 2.6666666666666665, 1.8333333333333333, 1.5, 2.0, 0.6666666666666666, 2.833333333333333, 0.5, 8, 6), (7, '[광주출발] "코시롱한 제주나들이" 관광호텔 2박3일 패키지 산방산유람선+승마체험', [37, 78, 60, 58], 1.5, 2.25, 1.5, 1.25, 1.75, 0.75, 2.75, 1.5, 10, 4), (8, '[광주출발]고품격 노팁 노옵션 관광호텔 2박3일 패키지 해저잠수함+잠수함+워터서커스+전일정식사포함', [37, 602, 78, 65, 118, 58], 2.0, 2.333333333333333, 1.5, 1.5, 1.6666666666666667, 1.3333333333333333, 2.333333333333333, 1.0, 10, 6), (9, '[부산출발][코시롱한나들이]♥감귤타르트증정♥제주 아쿠아플라넷 아스타호텔 3일', [78, 60, 29], 0.6666666666666666, 1.0, 1.3333333333333333, 1.0, 2.0, 1.3333333333333333, 2.333333333333333, 1.3333333333333333, 2, 3), (10, '[부산출발][노팁노옵션]♥흑돼지육포증정♥제주 잠수함여행 아스타호텔 3일', [78, 118, 9], 2.0, 1.6666666666666667, 1.6666666666666667, 1.6666666666666667, 1.3333333333333333, 2.0, 2.6666666666666665, 1.0, 11, 3), (11, '[부산출발][섬속의섬]♥감귤타르트증정♥우도투어+비밀의그림자공연 제주 아스타호텔 3일', [78, 10, 2], 1.6666666666666667, 1.6666666666666667, 1.6666666666666667, 1.0, 2.333333333333333, 1.3333333333333333, 2.333333333333333, 1.0, 10, 3), (12, '[부산출발][알뜰패키지_4인1실] 비밀의그림자공연+일출랜드 제주 관광호텔 3일', [78, 9, 106], 1.6666666666666667, 2.0, 1.6666666666666667, 1.0, 2.333333333333333, 2.0, 2.6666666666666665, 1.0, 10, 3), (13, '[싸다제주!!]제주 관광호텔 3일 - 서광곶자왈 + 웰빙족욕 비밀의그림자공연+서광곶자왈+웰빙족욕', [37, 78, 202, 58], 1.5, 2.25, 1.5, 1.5, 1.5, 1.5, 2.75, 1.25, 10, 4), (14, '[코시롱한나들이] 신나는여름! 떠나요제주! 관광호텔 3일 산방산유람선+아쿠아플라넷+서광곶자왈+웰빙족욕', [37, 78, 60, 202, 58, 29], 1.3333333333333333, 2.0, 1.5, 1.3333333333333333, 1.8333333333333333, 1.1666666666666667, 2.6666666666666665, 1.0, 10, 6), (15, '[노팁노옵션 PERFECT 마라도투어] 제주 관광호텔 2박3일 카멜리아힐+마라도탐방+승마체험+아쿠아플라넷+오션아레나공연', [138, 90, 10, 53, 602, 202, 58, 29], 1.875, 2.5, 1.875, 1.5, 2.375, 1.0, 2.375, 0.25, 3, 8), (16, '[고품격효도관광추천]푸른바다속잠수함탐험 노팁노옵션 관광호텔 3일 해저잠수함+웰빙족욕+승마체험+전일정식사', [37, 78, 1029, 65, 202, 58, 9], 1.7142857142857142, 2.142857142857143, 1.7142857142857142, 1.4285714285714286, 1.5714285714285714, 1.2857142857142858, 2.857142857142857, 0.8571428571428571, 10, 7), (17, '[효도관광추천] 노팁노옵션 제주관광호텔 2박3일<잠수함+스카이워터쇼> 수목원테마파크+그림자공연+승마+족욕+전일정식사', [37, 78, 1029, 202, 58, 9], 1.5, 2.0, 1.5, 1.6666666666666667, 1.5, 1.5, 2.833333333333333, 0.8333333333333334, 11, 6), (18, '[알뜰제주] 제주 관광호텔 2박3일 카멜리아힐+한담산책로+화순곶자왈+웰빙족욕', [19, 10, 602, 202, 58], 1.8, 2.8, 1.4, 1.2, 2.4, 1.2, 2.2, 0.2, 3, 5), (19, '[제주힐링여행] 한라산트래킹 관광호텔 2박3일 한라산등반+섭지코지+한울랜드', [37, 202, 58, 9], 2.25, 3.0, 2.0, 1.5, 2.0, 0.75, 3.0, 0.5, 8, 4), (20, '[노팁노옵션 PERFECT 마라도투어] 제주관광호텔 3일 최남단마라도,아쿠아플라넷, 족욕, 노팁, 노옵션', [138, 90, 10, 53, 602, 202, 58, 29, 9], 2.0, 2.555555555555556, 2.0, 1.4444444444444444, 2.4444444444444446, 0.8888888888888888, 2.4444444444444446, 0.2222222222222222, 8, 9), (21, '[환상의섬우도] 설레임 가득 제주 관광호텔 3일-마유비누증정 우도8경+비밀의그림자공연', [37, 65, 78, 202, 58, 2], 2.0, 2.5, 2.0, 1.1666666666666667, 1.8333333333333333, 1.0, 2.833333333333333, 1.0, 0, 6), (22, '[환상의섬우도] 설레임 가득 제주 관광호텔 3일 우도8경, 비밀의그림자공연, 승마체험', [37, 78, 10, 202, 58, 2], 1.8333333333333333, 2.333333333333333, 1.6666666666666667, 1.3333333333333333, 2.0, 1.1666666666666667, 2.6666666666666665, 0.8333333333333334, 0, 6), (23, '[ ...

# %%
result = pd.DataFrame(result)
result.columns = ['id','title','places','nature','outdoor','fatigue','sea','walking','exciting','day','culture','cluster','length']
result.head(2)
# Out:
#    id                                              title  \
# 0   1  [청주출발]연합패키지 제주를 반하다 3일_관광호텔 화순곶자왈+서커스+석예원한방족욕+...
# 1   2  [청주출발]연합패키지 노팁/노옵션 제주 3일_관광호텔 산방산유람선+ 화순곶자왈+서커...
#
#                           places    nature   outdoor   fatigue       sea  \
# 0              [602, 10, 58, 29]  1.250000  2.000000  1.250000  1.250000
# 1  [19, 37, 10, 602, 60, 58, 29]  1.714286  2.428571  1.285714  1.428571
#
#     walking  exciting       day   culture  cluster  length
# 0  2.750000  1.000000  1.750000  0.250000        3       4
# 1  2.571429  0.571429  2.285714  0.428571        3       7

# %%
joined_course.head(2)
# Out:
#    id  east  west  south  north main_location
# 0   1   2.0   1.0    0.0    1.0         Mixed
# 1   2   2.0   2.0    0.0    3.0         Mixed

# %%
join_result = result.merge(joined_course,on='id',how='inner')

# %%
join_result
# Out:
#         id                                              title  \
# 0        1  [청주출발]연합패키지 제주를 반하다 3일_관광호텔 화순곶자왈+서커스+석예원한방족욕+...
# 1        2  [청주출발]연합패키지 노팁/노옵션 제주 3일_관광호텔 산방산유람선+ 화순곶자왈+서커...
# 2        3  [부산출발_※3일차 석식 전복죽포함※]연합패키지 제주를 반하다 3일_관광호텔 화순곶...
# 3        4      [청주출발]"모두 알뜰 패키지" 제주 관광호텔 2박3일 비밀의 그림자+ 웰빙 족욕
# 4        5  [청주출발]◈감귤타르트증정/코시롱한나들이◈아쿠아플라넷+유람선-제주 로베로관광호텔 2...
# ...    ...                                                ...
# 3806  3807                                                제주도
# 3807  3808                                              Jeju!
# 3808  3809                                              제주도여행
# 3809  3810                                               제주도!
# 3810  3811                                               여름휴가
#
#                                                  places    nature   outdoor  \
# 0                                     [602, 10, 58, 29]  1.250000  2.000000
# 1                         [19, 37, 10, 602, 60, 58, 29]  1.714286  2.428571
# 2                                 [19, 602, 10, 58, 29]  1.400000  2.200000
# 3                                         [37, 202, 58]  2.000000  3.000000
# 4                                 [37, 60, 202, 58, 29]  1.600000  2.400000
# ...                                                 ...       ...       ...
# 3806           [59, 8, 5, 3, 439, 6, 22, 10, 24, 15, 9]  2.454545  2.636364
# 3807  [37, 144, 8, 78, 456, 66, 62, 49, 162, 5, 88, ...  2.000000  2.444444
# 3808               [18, 15, 87, 29, 9, 5, 179, 112, 61]  1.444444  2.000000
# 3809                     [22, 62, 5, 75, 284, 142, 172]  1.000000  1.000000
# 3810  [37, 103, 192, 439, 13, 6, 4, 140, 310, 134, 3...  2.380952  2.809524
#
#        fatigue       sea   walking  exciting       day   culture  cluster  \
# 0     1.250000  1.250000  2.750000  1.000000  1.750000  0.250000        3
# 1     1.285714  1.428571  2.571429  0.571429  2.285714  0.428571        3
# 2     1.200000  1.400000  2.800000  0.800000  2.000000  0.200000        3
# 3     1.666667  1.666667  1.666667  1.000000  3.000000  0.666667        6
# 4     1.600000  1.400000  2.000000  0.800000  2.800000  0.600000        3
# ...        ...       ...       ...       ...       ...       ...      ...
# 3806  1.454545  1.363636  1.818182  0.909091  2.090909  0.181818        1
# 3807  1.500000  1.277778  1.388889  1.166667  2.666667  1.000000       10
# 3808  1.333333  1.000000  1.666667  1.111111  2.444444  0.444444        9
# 3809  0.857143  1.000000  1.142857  0.857143  1.714286  1.571429        2
# 3810  1.857143  1.761905  2.333333  0.761905  2.571429  0.285714        8
#
#       length  east  west  south  north main_location
# 0          4   2.0   1.0    0.0    1.0         Mixed
# 1          7   2.0   2.0    0.0    3.0         Mixed
# 2          5   2.0   1.0    0.0    2.0         Mixed
# 3          3   1.0   0.0    0.0    2.0         North
# 4          5   2.0   1.0    0.0    2.0         Mixed
# ...      ...   ...   ...    ...    ...           ...
# 3806      11   4.0   4.0    2.0    1.0         Mixed
# 3807      18   5.0   3.0    6.0    4.0         Mixed
# 3808       9   2.0   1.0    5.0    1.0         South
# 3809       7   0.0   3.0    2.0    2.0         Mixed
# 3810      21  11.0   1.0    0.0    9.0          East
#
# [3811 rows x 18 columns]

# %%
join_result.to_csv("/content/drive/MyDrive/yeoreodigm/data_files/08.09_course.csv")

# %% [markdown]
# ##DB에 반영

# %%
from tqdm import tqdm

# %%
db= load_db()
cursor = db.cursor()

# %%
db.rollback()

# %%
for crs in tqdm(join_result.values):
  cursor.execute("insert into course_(title,places,nature,outdoor,fatigue,sea,walking,exciting,day,culture,cluster,length,east,west,south,north,main_location) VALUES(%s, %s, %s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s,%s, %s, %s)",(crs[1],crs[2],crs[3],crs[4],crs[5],crs[6],crs[7],crs[8],crs[9],crs[10],crs[11],crs[12],crs[13],crs[14],crs[15],crs[16],crs[17]))
db.commit()
# Out:
# 100%|██████████| 3811/3811 [11:08<00:00,  5.70it/s]

# %% [markdown]
# ##Lambda에 적용

# %%
import json
import pandas as pd
import psycopg2
import numpy as np
import os
from sklearn.metrics.pairwise import cosine_similarity
from itertools import combinations

def load_db():
  endpoint = os.environ['END_POINT']
  dbname = os.environ['DB_NAME']
  user = os.environ['USER_NAME']
  password = os.environ['WONSEOK']
  db = psycopg2.connect(host=endpoint,dbname=dbname,user=user,password=password)
  return db

def calculate_taste(user_id,db):
  cursor = db.cursor()
  load_survey_sql = f'SELECT result FROM survey_result WHERE member_id = {user_id};'
  cursor.execute(load_survey_sql)
  result = cursor.fetchone()
  survey_result = result[0]
  print(survey_result)

  theme_score = np.array([0]*8)
  for place in survey_result:
    load_place_sql = f'SELECT nature,outdoor,fatigue,sea,walking,exciting,day,culture FROM places_analysis WHERE place_id={place}'
    cursor.execute(load_place_sql)
    place_theme = cursor.fetchone()
    
    theme_score += np.array(place_theme)
    print('place : ',place,"\tnow : ",place_theme)

  result = theme_score / len(survey_result)
  return result


def path_divider(day,path):
  path_per_day = []
  checker = day

  length = len(path)
  print('length :',length )

  remainder = length%day
  quotient = length//day

  start = 0
  check=0

  while start<length:
    print(path[start:start + quotient + check])
    path_per_day.append(path[start:start + quotient + check])
    start += quotient+check
    checker-=1
    if checker<=remainder:
      check = 1

  return path_per_day

# %%
def load_course(day,db,include,location):
  cursor= db.cursor()
  min_length = 2*day
  max_length = 4*day
  length = len(include)
  count = 0
  location_count = len(location)
  if location_count == 4 or location_count == 0:
    location_sql = ' and 1=1'
  #case 2 : 한 지역만 선택한 경우 
  elif location_count == 1:
    location_sql = f" and main_location = \'{location[0]}\'"
  #case 3 : 여러 지역을 선택한 경우
  else:
    if location_count == 2:
      location_sql = f" and main_location = 'Mixed' and {location[0]} >0 and {location[1]} >0"
    elif location_count == 3:
      location_sql = f" and main_location = 'Mixed' and {location[0]} >0 and {location[1]} >0 and {location[2]} >0"


  df = pd.DataFrame()
  while length >= count:
    possible_cases = list(combinations(include,length-count))
    ##sql query 날리고 결과 받아서
    for now in possible_cases:
      print("now : ",list(now))
      now_include = list(now)
      load_course_sql= (f"SELECT id,title,nature,outdoor,fatigue,sea,walking,exciting,day,culture,cluster,places, main_location\
 FROM course_ WHERE length>={min_length} and length<={max_length} and array{now_include}::smallint[] <@ places" + location_sql)
      #해당 query문으로 query 날려서 결과가 있는지 확인해야함.
      
      cursor.execute(load_course_sql)
      result = cursor.fetchall()

      #현재 포함시킬 place를 모두 가지는 코스가 없는경우 
      if len(result) == 0:
        continue
      #현재 Place를 모두 포함하는 코스가 있는경우
      else:
        print("현재 now를 포함하는 df : \n",pd.DataFrame(result),"\n****************************\n")
        df = pd.concat([df, pd.DataFrame(result)])
    
    #dataframe에 값이 존재하면 (최적의 코스를 찾았다면)
    if not df.empty:
      break    
    count += 1
  
  #해당 조건에 만족하는 코스가 없는 경우
  if df.empty:
    print("no course")
    return df

  df.columns = ['id','title','nature','outdoor','fatigue','sea','walking','exciting','day','culture','cluster','places','main_location']

  return df
  #intersect 밖의 place를 모든 df의 Places list에 append 해줘야함.

# %%
def recommend_by_theme(user_id, day, include_list,location,db):
  top = 5
  course = load_course(day,db,include_list,location)
  if course.empty:
    print("empty course")
    return None

  user_taste = calculate_taste(user_id,db)
  user_taste = user_taste.reshape(1,-1)

  tag = ['nature','outdoor','fatigue','sea','walking','exciting','day','culture']

  print(user_taste)
  
  similarity = cosine_similarity(user_taste, course[tag])
  similarity = similarity[0]
  print(similarity.shape)
      
  print('similarity : ',similarity)
  
  result_index = similarity.argsort()
  result_index = result_index
  
  print("result_index : ",result_index)

  for i in range(-1,-(len(result_index)+1),-1):
    now_idx = result_index[i]
    sim = similarity[now_idx]
    print("similarity : ",sim,"df index : ",now_idx)

  top_N_result = result_index[-1:-(top+1):-1]
  print("top_N_result",top_N_result)
  
  #결과는 가장 일치율이 높은거 1개의 index만 던져주자
  result = top_N_result[0]
  result_df = course.iloc[result]
  print(result_df)
  
  not_included_places = list(set(include_list) - set(result_df['places']))
  if 0 not in include_list:
    result_df['places'] += not_included_places
  
  path = path_divider(day,result_df['places'])
  print('path : ',path)
  return path

# %%
my_location = ['East','West','South','North']
duration = 4
id= 184
include = [3,17,45]

# %%
check_result = recommend_by_theme(user_id = id, day=duration, include_list=include, location = my_location,db=db)
# Out:
# now :  [3, 17, 45]
# now :  [3, 17]
# 현재 now를 포함하는 df :
#         0                         1         2         3         4         5   \
# 0      77             깐수&꼉이의 제주 여행기  2.200000  2.300000  1.600000  1.300000
# 1     147  25만원으로 혼자 떠난 제주도 3박4일 여행  2.533333  3.000000  2.000000  2.000000
# 2     149            2박 3일 제주 기본 일정  2.312500  2.375000  1.375000  1.312500
# 3     193     ?제주 뚜벅이 버스여행? ???=333  2.384615  2.769231  1.615385  1.923077
# 4     206          처자들끼리 버스로 제주 누비기  2.363636  2.636364  1.454545  1.454545
# ..    ...                       ...       ...       ...       ...       ...
# 122  3657                       제주도  2.384615  2.538462  1.538462  1.076923
# 123  3665                     제주도여행  2.562500  2.937500  1.750000  1.187500
# 124  3693       2015.04.25~27 제주도여행  2.272727  2.727273  1.545455  1.454545
# 125  3707                         ★  2.500000  2.875000  2.125000  1.125000
# 126  3760                 설레이는 제주여행  2.363636  2.545455  1.909091  1.272727
#
#            6         7         8         9   10  \
# 0    2.300000  0.700000  2.300000  0.200000   4
# 1    2.533333  1.066667  3.000000  0.200000   8
# 2    1.625000  0.500000  2.312500  0.562500   1
# 3    1.923077  0.615385  2.692308  0.461538   4
# 4    2.000000  0.454545  2.272727  0.545455   4
# ..        ...       ...       ...       ...  ..
# 122  1.769231  0.538462  1.769231  0.076923   1
# 123  2.187500  0.625000  2.500000  0.375000   4
# 124  1.818182  0.363636  2.363636  0.818182   0
# 125  2.250000  0.625000  2.875000  0.250000   8
# 126  2.181818  0.818182  2.454545  0.181818   4
#
#                                                     11     12
# 0             [10, 22, 17, 3, 336, 310, 13, 80, 21, 1]  Mixed
# 1    [25, 13, 8, 2, 134, 219, 310, 3, 270, 17, 23, ...  Mixed
# 2    [103, 8, 22, 24, 16, 20, 3, 9, 6, 72, 74, 5, 4...  Mixed
# 3    [5, 38, 16, 17, 61, 2, 310, 134, 336, 3, 52, 1...   East
# 4          [1, 3, 3, 16, 20, 112, 61, 17, 38, 37, 223]  Mixed
# ..                                                 ...    ...
# 122   [439, 2, 3, 4, 21, 1, 15, 17, 5, 20, 10, 22, 38]  Mixed
# 123  [6, 439, 13, 3, 8, 28, 14, 4, 26, 18, 20, 17, ...  Mixed
# 124         [83, 3, 58, 5, 49, 112, 20, 17, 35, 8, 37]  Mixed
# 125                      [6, 4, 3, 9, 15, 17, 59, 244]  Mixed
# 126             [59, 8, 10, 15, 3, 9, 29, 17, 5, 2, 6]  Mixed
#
# [127 rows x 13 columns]
# ****************************
#
# now :  [3, 45]
# now :  [17, 45]
# [32, 19, 13, 6, 33, 8, 10, 25, 41, 72]
# place :  32 	now :  (2, 3, 1, 1, 3, 1, 3, 0)
# place :  19 	now :  (2, 3, 1, 2, 3, 0, 3, 0)
# place :  13 	now :  (2, 3, 1, 3, 3, 1, 3, 0)
# place :  6 	now :  (3, 2, 1, 1, 2, 1, 3, 1)
# place :  33 	now :  (0, 0, 1, 1, 0, 3, 2, 0)
# place :  8 	now :  (2, 3, 2, 3, 2, 2, 3, 0)
# place :  10 	now :  (2, 2, 1, 1, 3, 1, 2, 0)
# place :  25 	now :  (2, 3, 2, 3, 3, 2, 3, 0)
# place :  41 	now :  (2, 3, 1, 1, 1, 2, 3, 0)
# place :  72 	now :  (3, 3, 3, 0, 2, 0, 3, 0)
# [[2.  2.5 1.4 1.6 2.2 1.3 2.8 0.1]]
# (127,)
# similarity :  [0.98684304 0.99397507 0.97547801 0.9830227  0.97586528 0.96729135
#  0.97691676 0.98755324 0.98973276 0.97650638 0.99550868 0.98121453
#  0.98749973 0.95768678 0.98072828 0.98781807 0.97219254 0.9775264
#  0.99335837 0.97917433 0.99341721 0.95767044 0.97462272 0.99303426
#  0.97949885 0.96335901 0.95928972 0.9747656  0.99451577 0.98647587
#  0.99048902 0.97573767 0.97972643 0.97595943 0.97766189 0.97827741
#  0.98592475 0.96970173 0.99467067 0.98439671 0.96355327 0.97681747
#  0.9595172  0.98809653 0.97786662 0.99043295 0.99230093 0.98977805
#  0.97997779 0.9909965  0.98195674 0.97960766 0.98763173 0.97340573
#  0.97885482 0.98062297 0.98042884 0.98893206 0.99257321 0.96670872
#  0.9867761  0.96366096 0.98783314 0.97189844 0.98656049 0.97116903
#  0.98995132 0.98504956 0.99406836 0.96533694 0.97249869 0.98643085
#  0.98819123 0.98459543 0.98691844 0.98085714 0.98062221 0.96542813
#  0.97322884 0.9786707  0.9900377  0.98705585 0.98831847 0.96804824
#  0.99123129 0.98736058 0.98242842 0.98472278 0.9709394  0.98770601
#  0.99004584 0.9718288  0.97894311 0.97409386 0.96501209 0.98488179
#  0.97583583 0.98888615 0.98911246 0.98911986 0.96520433 0.96418374
#  0.98399752 0.98676134 0.9855698  0.98086196 0.98840438 0.97505583
#  0.9847416  0.95933622 0.99075102 0.98152783 0.9801762  0.98892617
#  0.97102229 0.9790914  0.98356913 0.98456031 0.98318565 0.9750959
#  0.93991323 0.98206881 0.96462917 0.97703519 0.96694585 0.9772228
#  0.9851961 ]
# result_index :  [120  21  13  26 109  42  25  40  61 101 122  94 100  69  77  59 124   5
#   83  37  88 114  65  91  63  16  70  78  53  93  22  27 107 119   2  31
#   96   4  33   9  41   6 123 125  17  34  44  35  79  54  92 115  19  24
#   51  32  48 112  56  76  55  14  75 105  11 111  50 121  86   3 118 116
#  102  39 117  73  87 108  95  67 126 104  36  71  29  64 103  60   0  74
#   81  85  12   7  52  89  15  62  43  72  82 106  97 113  57  98  99   8
#   47  66  80  90  45  30 110  49  84  46  58  23  18  20   1  68  28  38
#   10]
# similarity :  0.9955086843177372 df index :  10
# similarity :  0.9946706742602043 df index :  38
# similarity :  0.9945157714660215 df index :  28
# similarity :  0.994068357479001 df index :  68
# similarity :  0.9939750663757116 df index :  1
# similarity :  0.9934172060349263 df index :  20
# similarity :  0.9933583737702906 df index :  18
# similarity :  0.9930342626425464 df index :  23
# similarity :  0.9925732074450334 df index :  58
# similarity :  0.9923009328127472 df index :  46
# similarity :  0.9912312902457969 df index :  84
# similarity :  0.9909965045554734 df index :  49
# similarity :  0.9907510225496866 df index :  110
# similarity :  0.9904890239235759 df index :  30
# similarity :  0.9904329455100351 df index :  45
# similarity :  0.9900458415970885 df index :  90
# similarity :  0.9900377003767991 df index :  80
# similarity :  0.9899513213811875 df index :  66
# similarity :  0.9897780526772876 df index :  47
# similarity :  0.989732760835213 df index :  8
# similarity :  0.9891198563001004 df index :  99
# similarity :  0.9891124581048204 df index :  98
# similarity :  0.9889320598719034 df index :  57
# similarity :  0.9889261725086856 df index :  113
# similarity :  0.9888861542850385 df index :  97
# similarity :  0.9884043786184444 df index :  106
# similarity :  0.9883184713902351 df index :  82
# similarity :  0.9881912283763101 df index :  72
# similarity :  0.9880965260671681 df index :  43
# similarity :  0.9878331434702721 df index :  62
# similarity :  0.9878180679115052 df index :  15
# similarity :  0.9877060118505667 df index :  89
# similarity :  0.9876317279778749 df index :  52
# similarity :  0.9875532390256825 df index :  7
# similarity :  0.9874997322109528 df index :  12
# similarity :  0.9873605776862162 df index :  85
# similarity :  0.987055850501658 df index :  81
# similarity :  0.9869184445212954 df index :  74
# similarity :  0.9868430405585531 df index :  0
# similarity :  0.9867760985219574 df index :  60
# similarity :  0.9867613366029717 df index :  103
# similarity :  0.9865604937739811 df index :  64
# similarity :  0.9864758731821561 df index :  29
# similarity :  0.9864308501372137 df index :  71
# similarity :  0.9859247519285692 df index :  36
# similarity :  0.9855697977947685 df index :  104
# similarity :  0.98519609816675 df index :  126
# similarity :  0.9850495579934033 df index :  67
# similarity :  0.9848817877210729 df index :  95
# similarity :  0.9847416033665807 df index :  108
# similarity :  0.98472278238096 df index :  87
# similarity :  0.9845954322444428 df index :  73
# similarity :  0.9845603088132753 df index :  117
# similarity :  0.9843967067374043 df index :  39
# similarity :  0.9839975216128194 df index :  102
# similarity :  0.9835691342299324 df index :  116
# similarity :  0.9831856457680872 df index :  118
# similarity :  0.9830226964066849 df index :  3
# similarity :  0.982428416400407 df index :  86
# similarity :  0.9820688120198793 df index :  121
# similarity :  0.9819567435972603 df index :  50
# similarity :  0.9815278262409235 df index :  111
# similarity :  0.9812145262891916 df index :  11
# similarity :  0.9808619630738483 df index :  105
# similarity :  0.9808571370688026 df index :  75
# similarity :  0.9807282780810924 df index :  14
# similarity :  0.9806229747838909 df index :  55
# similarity :  0.9806222126569363 df index :  76
# similarity :  0.9804288368331147 df index :  56
# similarity :  0.9801762021187186 df index :  112
# similarity :  0.9799777894571446 df index :  48
# similarity :  0.9797264311166767 df index :  32
# similarity :  0.979607655424297 df index :  51
# similarity :  0.979498845673294 df index :  24
# similarity :  0.9791743297607794 df index :  19
# similarity :  0.9790914017920633 df index :  115
# similarity :  0.9789431064225598 df index :  92
# similarity :  0.9788548176256817 df index :  54
# similarity :  0.9786707016423504 df index :  79
# similarity :  0.9782774102304815 df index :  35
# similarity :  0.977866622588592 df index :  44
# similarity :  0.9776618859962038 df index :  34
# similarity :  0.9775264047888876 df index :  17
# similarity :  0.977222800060731 df index :  125
# similarity :  0.9770351853552488 df index :  123
# similarity :  0.976916760302815 df index :  6
# similarity :  0.9768174737974455 df index :  41
# similarity :  0.9765063761695205 df index :  9
# similarity :  0.9759594260434659 df index :  33
# similarity :  0.9758652751360206 df index :  4
# similarity :  0.9758358338440258 df index :  96
# similarity :  0.9757376732338012 df index :  31
# similarity :  0.9754780052477785 df index :  2
# similarity :  0.9750958958192889 df index :  119
# similarity :  0.9750558293602994 df index :  107
# similarity :  0.9747655972507814 df index :  27
# similarity :  0.974622719699637 df index :  22
# similarity :  0.9740938565511551 df index :  93
# similarity :  0.9734057315935876 df index :  53
# similarity :  0.9732288372620249 df index :  78
# similarity :  0.9724986902216117 df index :  70
# similarity :  0.9721925374119169 df index :  16
# similarity :  0.9718984445435608 df index :  63
# similarity :  0.9718287951802045 df index :  91
# similarity :  0.9711690255542687 df index :  65
# similarity :  0.9710222911767341 df index :  114
# similarity :  0.9709394022481438 df index :  88
# similarity :  0.9697017343126704 df index :  37
# similarity :  0.9680482428160733 df index :  83
# similarity :  0.9672913456231647 df index :  5
# similarity :  0.9669458533656248 df index :  124
# similarity :  0.9667087233438116 df index :  59
# similarity :  0.9654281332816979 df index :  77
# similarity :  0.9653369376286678 df index :  69
# similarity :  0.9652043279562105 df index :  100
# similarity :  0.965012086998834 df index :  94
# similarity :  0.9646291696170595 df index :  122
# similarity :  0.9641837415589946 df index :  101
# similarity :  0.9636609607075362 df index :  61
# similarity :  0.9635532717035673 df index :  40
# similarity :  0.9633590123516107 df index :  25
# similarity :  0.9595171960829623 df index :  42
# similarity :  0.9593362214839957 df index :  109
# similarity :  0.9592897172600392 df index :  26
# similarity :  0.957686781753972 df index :  13
# similarity :  0.9576704418949187 df index :  21
# similarity :  0.9399132267884753 df index :  120
# top_N_result [10 38 28 68  1]
# id                                                        322
# title                                                꿀꿀이랑 제주도
# nature                                               1.909091
# outdoor                                              2.272727
# fatigue                                              1.636364
# sea                                                  1.181818
# walking                                              2.090909
# exciting                                             1.090909
# day                                                  2.636364
# culture                                              0.090909
# cluster                                                     3
# places           [3, 29, 9, 30, 18, 17, 79, 581, 179, 22, 59]
# main_location                                           Mixed
# Name: 10, dtype: object
# length : 12
# [3, 29, 9]
# [30, 18, 17]
# [79, 581, 179]
# [22, 59, 45]
# path :  [[3, 29, 9], [30, 18, 17], [79, 581, 179], [22, 59, 45]]
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:1056: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cacher_needs_updating = self._check_is_chained_assignment_possible()

# %%
print(check_result)
# Out:
# [[5, 38, 16], [17, 61, 2], [310, 134, 336, 3], [52, 13, 25, 45]]

# %%
check_result
# Out:
# [[80, 13], [30, 219], [76, 10, 38], [22, 174, 8]]

# %%
join_result[join_result['id']==2566]
# Out:
#         id    title                                             places  \
# 2565  2566  혜리랑 제주도  [25, 223, 707, 317, 379, 91, 4, 42, 179, 223, ...
#
#       nature  outdoor  fatigue     sea  walking  exciting   day  culture  \
# 2565   2.125   2.6875    1.625  1.6875     2.25      1.25  2.75   0.0625
#
#       cluster  length  east  west  south  north main_location
# 2565        5      16   7.0   4.0    1.0    4.0         Mixed

# %% [markdown]
# ##코스 확인용 df 변환 메소드 : df를 받으면 places id리스트를 title 리스트로 변환해주는 역할

# %%
attraction = pd.read_csv("/content/drive/MyDrive/yeoreodigm/data_files/07.31_attraction_db.csv",index_col=0)

# %%
attraction.sample()
# Out:
#       id title                       address     introduction   latitude  \
# 692  693   법화사  제주특별자치도 서귀포시 하원북로 35번길 15-28  제주 천년고찰의 법화사이다.  33.265095
#
#      longitude      dial_num type region1 region2  ... nature  outdoor  \
# 692  126.45783  064-738-5225  관광지    서귀포시   서귀포시내  ...      2        1
#
#      fatigue  sea  walking  exciting  day  culture  group   tag
# 692        0    1        0         0    3        2     12  문화관광
#
# [1 rows x 22 columns]

# %%
def id_to_title(course_df,attraction_df):
  places = course_df['places'].values[0]
  title_list = []
  for i in places:
    now = attraction_df.loc[attraction_df['id']==i,'title']
    title_list.append(now)
  return title_list

# %%
tt = id_to_title(join_result[join_result['id']==2566],attraction)

# %%
attraction.loc[attraction['id']==223]
# Out:
#       id     title             address  \
# 222  223  이호테우해수욕장  제주특별자치도 제주시 도리로 20
#
#                                       introduction   latitude   longitude  \
# 222  붉은 조랑말과 흰 조랑말의 극명하게 대조되는 색감이 이국적인 풍경을 선사하는 해변  33.496185  126.455952
#
#          dial_num type region1 region2  ... nature  outdoor  fatigue  sea  \
# 222  064-728-4927  관광지     제주시    제주시내  ...      3        3        2    3
#
#      walking  exciting  day  culture  group                    tag
# 222        2         2    2        0      9  자연경관,포토스팟,해변,휴식/힐링,여름
#
# [1 rows x 22 columns]

# %%
# Out:
# [24    김녕해수욕장
#  Name: title, dtype: object, 222    이호테우해수욕장
#  Name: title, dtype: object, 706    월정리해안도로
#  Name: title, dtype: object, 316    종달리해안도로
#  Name: title, dtype: object, 378    법환포구
#  Name: title, dtype: object, 90    아날로그감귤밭
#  Name: title, dtype: object, 3    비자림
#  Name: title, dtype: object, 41    제주김녕미로공원
#  Name: title, dtype: object, 178    이니스프리제주하우스
#  Name: title, dtype: object, 222    이호테우해수욕장
#  Name: title, dtype: object, 12    월정리해변
#  Name: title, dtype: object, 45    김경숙해바라기농장
#  Name: title, dtype: object, 8    섭지코지
#  Name: title, dtype: object, 173    성이시돌목장
#  Name: title, dtype: object, 294    낙천리아홉굿의자마을
#  Name: title, dtype: object, 9    카멜리아힐
#  Name: title, dtype: object]

# %% [markdown]
# ###08.08 lambda

# %%
#08.08 lambda
import json
import pandas as pd
import psycopg2
import numpy as np
import os
from sklearn.metrics.pairwise import cosine_similarity
from itertools import combinations

def load_db():
  endpoint = os.environ['END_POINT']
  dbname = os.environ['DB_NAME']
  user = os.environ['USER_NAME']
  password = os.environ['WONSEOK']
  db = psycopg2.connect(host=endpoint,dbname=dbname,user=user,password=password)
  return db

def calculate_taste(user_id,db):
  cursor = db.cursor()
  load_survey_sql = f'SELECT result FROM survey_result WHERE member_id = {user_id};'
  cursor.execute(load_survey_sql)
  result = cursor.fetchone()
  survey_result = result[0]
  print(survey_result)

  theme_score = np.array([0]*8)
  for place in survey_result:
    load_place_sql = f'SELECT nature,outdoor,fatigue,sea,walking,exciting,day,culture FROM places_analysis WHERE place_id={place}'
    cursor.execute(load_place_sql)
    place_theme = cursor.fetchone()
    
    theme_score += np.array(place_theme)
    print('place : ',place,"\tnow : ",place_theme)

  result = theme_score / len(survey_result)
  return result


def path_divider(day,path):
  path_per_day = []
  checker = day

  length = len(path)
  print('length :',length )

  remainder = length%day
  quotient = length//day

  start = 0
  check=0

  while start<length:
    print(path[start:start + quotient + check])
    path_per_day.append(path[start:start + quotient + check])
    start += quotient+check
    checker-=1
    if checker<=remainder:
      check = 1

  return path_per_day


def load_course(day,db,include):
  cursor= db.cursor()
  min_length = 2*day
  max_length = 4*day
  length = len(include)
  count = 0
  
  df = pd.DataFrame()
  while length >= count:
    possible_cases = list(combinations(include,length-count))
    ##sql query 날리고 결과 받아서
    for now in possible_cases:
      print("now : ",list(now))
      now_include = list(now)
      load_course_sql= (f"SELECT id,title,nature,outdoor,fatigue,sea,walking,exciting,day,culture,cluster,places\
 FROM course_ WHERE length>={min_length} and length<={max_length} and array{now_include}::smallint[] <@ places")
      #해당 query문으로 query 날려서 결과가 있는지 확인해야함.
      
      cursor.execute(load_course_sql)
      result = cursor.fetchall()

      #현재 포함시킬 place를 모두 가지는 코스가 없는경우 
      if len(result) == 0:
        continue
      #현재 Place를 모두 포함하는 코스가 있는경우
      else:
        print("현재 now를 포함하는 df : \n",pd.DataFrame(result),"\n****************************\n")
        df = pd.concat([df, pd.DataFrame(result)])
    
    #dataframe에 값이 존재하면 (최적의 코스를 찾았다면)
    if not df.empty:
      break    
    count += 1

  df.columns = ['id','title','nature','outdoor','fatigue','sea','walking','exciting','day','culture','cluster','places']

  return df
  #intersect 밖의 place를 모든 df의 Places list에 append 해줘야함.




def recommend_by_theme(user_id, day, include_list,db):
  top = 5
  course = load_course(day,db,include_list)
  user_taste = calculate_taste(user_id,db)
  user_taste = user_taste.reshape(1,-1)

  tag = ['nature','outdoor','fatigue','sea','walking','exciting','day','culture']

  print(user_taste)
  
  similarity = cosine_similarity(user_taste, course[tag])
  similarity = similarity[0]
  print(similarity.shape)
      
  print('similarity : ',similarity)
  
  result_index = similarity.argsort()
  result_index = result_index
  
  print("result_index : ",result_index)

  for i in range(-1,-(len(result_index)+1),-1):
    now_idx = result_index[i]
    sim = similarity[now_idx]
    print("similarity : ",sim,"df index : ",now_idx)

  top_N_result = result_index[-1:-(top+1):-1]
  print("top_N_result",top_N_result)
  
  #결과는 가장 일치율이 높은거 1개의 index만 던져주자
  result = top_N_result[0]
  result_df = course.iloc[result]
  print(result_df)
  
  not_included_places = list(set(include_list) - set(result_df['places']))
  if 0 not in include_list:
    result_df['places'] += not_included_places
  
  path = path_divider(day,result_df['places'])
  print('path : ',path)
  return path
  
def lambda_handler(event, context):

  id = int(event['queryStringParameters']['id'])
  day = int(event['queryStringParameters']['day'])
  include = list(map(int,event['queryStringParameters']['include'].split(',')))
  
  try:
    db = load_db()
  except:
        return {
            "success": False,
            "message": "Database Error",
        }
  result_path = recommend_by_theme(id, day,include,db)
  
  

  return {
      'statusCode': 200,
      'body': json.dumps({  
                            "courseList" : result_path,
                            })
  }
