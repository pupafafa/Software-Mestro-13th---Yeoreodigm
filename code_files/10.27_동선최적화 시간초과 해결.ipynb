# %%
# !pip install haversine
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting haversine
#   Downloading haversine-2.7.0-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: haversine
# Successfully installed haversine-2.7.0

# %%
import json
import psycopg2
import os 
import numpy as np
from haversine import haversine
from itertools import combinations
JEJU_AIRPORT = (0,33.5059364, 126.4959513)

# %%
def load_db():
  with open("/content/drive/MyDrive/yeoreodigm/data_files/db_info.json") as json_file:
    DB_INFO = json.load(json_file)
  
  endpoint = DB_INFO["ENDPOINT"]
  dbname = DB_INFO["DB_NAME"]
  user = DB_INFO["USER_ID"]
  password = DB_INFO["PASSWORD"]
  db = psycopg2.connect(host=endpoint,dbname=dbname,user=user,password=password)
  return db

# %% [markdown]
# ##너무 경우가 많은 경우는 path_divider로 단순하게 나누기

# %%
def path_divider(day,path):
  path_per_day = []
  checker = day

  length = len(path)
  print('length :',length )

  remainder = length%day
  quotient = length//day

  start = 0
  check=0

  while start<length:
    print(path[start:start + quotient + check])
    now_day_path = path[start:start + quotient + check]
    now_day_path = list(map(int,now_day_path))
    path_per_day.append(now_day_path)
    start += quotient+check
    checker-=1
    if checker<=remainder:
      check = 1

  return path_per_day

def load_places_location(db, place_list):
  cursor = db.cursor()
  place_list = str(tuple(place_list))
  print("place list : ",place_list)
  sql = f"select place_id, latitude, longitude from places where place_id in {place_list}"
  cursor.execute(sql)
  result = cursor.fetchall()
  result = list(map(list,result))
  return result
  
def calculate_distance_haversine(A,B):
  A_x = A[1]
  A_y = A[2]
  B_x = B[1]
  B_y = B[2]
  dist = haversine((A_x,A_y),(B_x,B_y))
  return dist
  
def make_dist_matrix_haversine(location_info):
  print("making matrix!!!")
  matrix_size = len(location_info)
  #initialize empty n*n matrix
  dist_matrix = [([0] * matrix_size) for _ in range(matrix_size)]
  for i in range(matrix_size):
    for j in range(i+1,matrix_size):
      dist_matrix[i][j] = calculate_distance_haversine(location_info[i],location_info[j])
      dist_matrix[j][i] = dist_matrix[i][j]
  return dist_matrix
  
def optimize_course(place_list,day,db):
  place_info = load_places_location(db, place_list)
  save_id = []  
  result = [[] for _ in range(day)]
  
  AIRPORT = (33.5059364,126.4959513)
  length = len(place_list)
  total_dist = [0]*length
  visit_result = [[] for _ in range(length)]

  dist_matrix = make_dist_matrix_haversine(place_info)

  for i in range(length):
    start = i
    end = 999
    visit = [False] * length
    visit[i] = True    
    now = i
    min_dist = 100
    min_idx = 999
    visit_result[i].append(now)
    print("start : ",start)
    while False in visit: #모든 클러스터를 방문할때까지
      for idx, dist in enumerate(dist_matrix[now]):
        if visit[idx] == True:
          continue
        else:
          if dist < min_dist:
            min_idx = idx
            min_dist = dist
      print("dist from %d to %d : %.2f  "%(now,min_idx,min_dist))
      
      total_dist[start] += min_dist
      now = min_idx
      visit[now] = True
      visit_result[start].append(now)
      min_dist=999
      end = min_idx

    airport_to_start = haversine(AIRPORT,place_info[start][1:]) # 공항에서 시작지점 까지 거리
    end_to_airport = haversine(AIRPORT,place_info[end][1:]) #마지막지점에서 공항 가는 거리
    total_dist[i] += airport_to_start 
    total_dist[i] += end_to_airport  

    print("airport - 시작지점(%s) 까지 거리%s 합산"%(start,airport_to_start))
    print("끝지점(%s) - 공항  까지 거리%s 합산"%(end,end_to_airport))
    print("total_dist : ",total_dist[i])

  shortest_cluster = np.array(total_dist).argsort()[0]
  result_index = visit_result[shortest_cluster]  #최단거리를 보장하는 index 방문 순서 마지막에 이 인덱스랑 Id랑 매핑해줘야함.
 

  #day dividing ...
  day_dividing = []
  print("result_index : ",result_index)
  print('조합 개수',len(list(combinations(result_index,day-1))))
  if len(list(combinations(result_index,day-1))) > 1e5:
    print("조합이 너무 많으니까 path divider로 단순하게 나눌거에요~ ㅎㅎ")
    final_result = path_divider(day,result_index)
    final_result2 = []
    for i in final_result:
      tmp_list = []
      print("i : ",i)
      for j in i:
        print("j : ",j)
        tmp_list.append(place_info[j][0])
      final_result2.append(tmp_list)
    return final_result2

  for comb in combinations(result_index,day-1):
    #comb : (5,3,7)
    #print("comb : ",comb)
    if comb[-1] == result_index[-1]: 
      continue
    dist = 0
    for now in comb:
      next = result_index[result_index.index(now) + 1]
      now_loc = place_info[now][1:]
      next_loc = place_info[next][1:]
      
      dist += haversine(now_loc,next_loc)
    day_dividing.append((dist,comb))
    
  day_dividing.sort(reverse = True) #내림차순 정렬
  
  
  for i in range(len(day_dividing)):
    divider = day_dividing[i][1]
    pass_token = 1
    print("divider : ",divider)
    
    final_result = []
    start = 0
    for i in divider:
      cut = result_index.index(i)  
      final_result.append(result_index[start:cut+1])
      if cut-start > 5: # 하루에 6곳 이상을 방문하는 경우
        pass_token = 0
        break
      start = cut+1

    if pass_token == 0:
      continue
    
    final_result.append(result_index[start:])
  

  #index -> id 전환
    final_result2 = []
    for i in final_result:
      tmp_list = []
      print("i : ",i)
      for j in i:
        print("j : ",j)
        tmp_list.append(place_info[j][0])
      final_result2.append(tmp_list)


    return final_result2

# %%
db=load_db()
p_list = [1,2,3,4,5,6,8,9,10,13,15,24,154,28,287,32,37,174,49,93,112,29,30,333,334,335,336,337,338,339,348,349,361,368]
a = optimize_course(p_list,9,db)
# Out:
# place list :  (1, 2, 3, 4, 5, 6, 8, 9, 10, 13, 15, 24, 154, 28, 287, 32, 37, 174, 49, 93, 112, 29, 30, 333, 334, 335, 336, 337, 338, 339, 348, 349, 361, 368)
# making matrix!!!
# start :  0
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# airport - 시작지점(0) 까지 거리17.43496801230598 합산
# 끝지점(25) - 공항  까지 거리28.629662634884795 합산
# total_dist :  254.76928436276836
# start :  1
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 32 : 11.41
# dist from 32 to 3 : 7.78
# dist from 3 to 14 : 1.04
# dist from 14 to 5 : 5.25
# dist from 5 to 9 : 3.89
# dist from 9 to 25 : 17.05
# dist from 25 to 0 : 12.65
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# airport - 시작지점(1) 까지 거리42.21742386626139 합산
# 끝지점(16) - 공항  까지 거리1.7444534347592144 합산
# total_dist :  246.2621192440584
# start :  2
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 26 : 7.78
# dist from 26 to 1 : 3.23
# dist from 1 to 32 : 6.22
# dist from 32 to 3 : 7.78
# dist from 3 to 14 : 1.04
# dist from 14 to 5 : 5.25
# dist from 5 to 9 : 3.89
# dist from 9 to 25 : 17.05
# dist from 25 to 0 : 12.65
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# airport - 시작지점(2) 까지 거리41.12900821221665 합산
# 끝지점(16) - 공항  까지 거리1.7444534347592144 합산
# total_dist :  243.41968233202013
# start :  3
# dist from 3 to 14 : 1.04
# dist from 14 to 5 : 5.25
# dist from 5 to 9 : 3.89
# dist from 9 to 32 : 8.57
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 0 : 12.65
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# airport - 시작지점(3) 까지 거리29.281628745192872 합산
# 끝지점(16) - 공항  까지 거리1.7444534347592144 합산
# total_dist :  226.0769488182574
# start :  4
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 28 : 1.79
# dist from 28 to 10 : 5.60
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 29 : 36.76
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# airport - 시작지점(4) 까지 거리29.64061814139395 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  276.01923833786554
# start :  5
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 0 : 12.65
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# airport - 시작지점(5) 까지 거리25.67716766261305 합산
# 끝지점(16) - 공항  까지 거리1.7444534347592144 합산
# total_dist :  224.61148921995166
# start :  6
# dist from 6 to 12 : 0.39
# dist from 12 to 27 : 0.00
# dist from 27 to 21 : 9.09
# dist from 21 to 20 : 7.42
# dist from 20 to 8 : 1.87
# dist from 8 to 19 : 5.96
# dist from 19 to 29 : 2.31
# dist from 29 to 17 : 10.37
# dist from 17 to 33 : 0.52
# dist from 33 to 23 : 0.49
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 10 : 5.60
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 11 : 48.19
# airport - 시작지점(6) 까지 거리26.87053242687733 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  272.4136005895142
# start :  7
# dist from 7 to 13 : 0.27
# dist from 13 to 2 : 3.37
# dist from 2 to 26 : 4.35
# dist from 26 to 1 : 3.23
# dist from 1 to 32 : 6.22
# dist from 32 to 3 : 7.78
# dist from 3 to 14 : 1.04
# dist from 14 to 5 : 5.25
# dist from 5 to 9 : 3.89
# dist from 9 to 25 : 17.05
# dist from 25 to 0 : 12.65
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# airport - 시작지점(7) 까지 거리40.95561449314911 합산
# 끝지점(16) - 공항  까지 거리1.7444534347592144 합산
# total_dist :  239.8124408362081
# start :  8
# dist from 8 to 20 : 1.87
# dist from 20 to 19 : 6.89
# dist from 19 to 29 : 2.31
# dist from 29 to 17 : 10.37
# dist from 17 to 33 : 0.52
# dist from 33 to 23 : 0.49
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 10 : 5.60
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 21 : 42.88
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# airport - 시작지점(8) 까지 거리26.759442363075724 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  282.1423649494491
# start :  9
# dist from 9 to 5 : 3.89
# dist from 5 to 14 : 5.25
# dist from 14 to 3 : 1.04
# dist from 3 to 32 : 7.78
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 0 : 12.65
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# airport - 시작지점(9) 까지 거리28.586027524980658 합산
# 끝지점(16) - 공항  까지 거리1.7444534347592144 합산
# total_dist :  224.59473464870212
# start :  10
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 30 : 31.70
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# airport - 시작지점(10) 까지 거리30.587017850379187 합산
# 끝지점(25) - 공항  까지 거리28.629662634884795 합산
# total_dist :  263.1580451526912
# start :  11
# dist from 11 to 20 : 8.86
# dist from 20 to 8 : 1.87
# dist from 8 to 19 : 5.96
# dist from 19 to 29 : 2.31
# dist from 29 to 17 : 10.37
# dist from 17 to 33 : 0.52
# dist from 33 to 23 : 0.49
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 10 : 5.60
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 21 : 42.88
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# airport - 시작지점(11) 까지 거리37.02048328138605 합산
# 끝지점(6) - 공항  까지 거리26.87053242687733 합산
# total_dist :  268.53840066282356
# start :  12
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 21 : 9.33
# dist from 21 to 20 : 7.42
# dist from 20 to 8 : 1.87
# dist from 8 to 19 : 5.96
# dist from 19 to 29 : 2.31
# dist from 29 to 17 : 10.37
# dist from 17 to 33 : 0.52
# dist from 33 to 23 : 0.49
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 10 : 5.60
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 11 : 48.19
# airport - 시작지점(12) 까지 거리27.033424095975544 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  272.8159338860804
# start :  13
# dist from 13 to 7 : 0.27
# dist from 7 to 2 : 3.63
# dist from 2 to 26 : 4.35
# dist from 26 to 1 : 3.23
# dist from 1 to 32 : 6.22
# dist from 32 to 3 : 7.78
# dist from 3 to 14 : 1.04
# dist from 14 to 5 : 5.25
# dist from 5 to 9 : 3.89
# dist from 9 to 25 : 17.05
# dist from 25 to 0 : 12.65
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# airport - 시작지점(13) 까지 거리40.89269052756408 합산
# 끝지점(16) - 공항  까지 거리1.7444534347592144 합산
# total_dist :  240.0106811765294
# start :  14
# dist from 14 to 3 : 1.04
# dist from 3 to 5 : 5.49
# dist from 5 to 9 : 3.89
# dist from 9 to 32 : 8.57
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 0 : 12.65
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# airport - 시작지점(14) 까지 거리28.35770740963443 합산
# 끝지점(16) - 공항  까지 거리1.7444534347592144 합산
# total_dist :  225.39019858066857
# start :  15
# dist from 15 to 24 : 0.00
# dist from 24 to 31 : 1.32
# dist from 31 to 0 : 2.99
# dist from 0 to 18 : 4.23
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# airport - 시작지점(15) 까지 거리14.048931362915768 합산
# 끝지점(25) - 공항  까지 거리28.629662634884795 합산
# total_dist :  253.1816047698036
# start :  16
# dist from 16 to 18 : 12.93
# dist from 18 to 15 : 2.43
# dist from 15 to 24 : 0.00
# dist from 24 to 31 : 1.32
# dist from 31 to 0 : 2.99
# dist from 0 to 22 : 5.96
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 25 : 48.19
# dist from 25 to 14 : 9.71
# dist from 14 to 3 : 1.04
# dist from 3 to 5 : 5.49
# dist from 5 to 9 : 3.89
# dist from 9 to 32 : 8.57
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# airport - 시작지점(16) 까지 거리1.7444534347592144 합산
# 끝지점(7) - 공항  까지 거리40.95561449314911 합산
# total_dist :  242.3030503610396
# start :  17
# dist from 17 to 33 : 0.52
# dist from 33 to 23 : 0.49
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 10 : 5.60
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 29 : 36.76
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# airport - 시작지점(17) 까지 거리29.92462899053896 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  275.30640090796317
# start :  18
# dist from 18 to 15 : 2.43
# dist from 15 to 24 : 0.00
# dist from 24 to 31 : 1.32
# dist from 31 to 0 : 2.99
# dist from 0 to 22 : 5.96
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# airport - 시작지점(18) 까지 거리13.24760650239183 합산
# 끝지점(25) - 공항  까지 거리28.629662634884795 합산
# total_dist :  249.4887335057936
# start :  19
# dist from 19 to 29 : 2.31
# dist from 29 to 8 : 8.25
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 17 : 21.77
# dist from 17 to 33 : 0.52
# dist from 33 to 23 : 0.49
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 10 : 5.60
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# airport - 시작지점(19) 까지 거리29.168650214704186 합산
# 끝지점(25) - 공항  까지 거리28.629662634884795 합산
# total_dist :  253.459320473266
# start :  20
# dist from 20 to 8 : 1.87
# dist from 8 to 19 : 5.96
# dist from 19 to 29 : 2.31
# dist from 29 to 17 : 10.37
# dist from 17 to 33 : 0.52
# dist from 33 to 23 : 0.49
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 10 : 5.60
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 21 : 42.88
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# airport - 시작지점(20) 까지 거리28.211704479249526 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  282.66519218401686
# start :  21
# dist from 21 to 20 : 7.42
# dist from 20 to 8 : 1.87
# dist from 8 to 19 : 5.96
# dist from 19 to 29 : 2.31
# dist from 29 to 17 : 10.37
# dist from 17 to 33 : 0.52
# dist from 33 to 23 : 0.49
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 10 : 5.60
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 11 : 48.19
# dist from 11 to 12 : 21.26
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# airport - 시작지점(21) 까지 거리24.024621225541654 합산
# 끝지점(6) - 공항  까지 거리26.87053242687733 합산
# total_dist :  271.5929607594199
# start :  22
# dist from 22 to 30 : 2.99
# dist from 30 to 0 : 7.92
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 10 : 22.12
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# airport - 시작지점(22) 까지 거리18.728210975575664 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  252.07245508194998
# start :  23
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 33 : 1.35
# dist from 33 to 17 : 0.52
# dist from 17 to 10 : 7.32
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 29 : 36.76
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# airport - 시작지점(23) 까지 거리29.898084841056583 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  277.86443683779567
# start :  24
# dist from 24 to 15 : 0.00
# dist from 15 to 31 : 1.32
# dist from 31 to 0 : 2.99
# dist from 0 to 18 : 4.23
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# airport - 시작지점(24) 까지 거리14.048931362915768 합산
# 끝지점(25) - 공항  까지 거리28.629662634884795 합산
# total_dist :  253.1816047698036
# start :  25
# dist from 25 to 14 : 9.71
# dist from 14 to 3 : 1.04
# dist from 3 to 5 : 5.49
# dist from 5 to 9 : 3.89
# dist from 9 to 32 : 8.57
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 0 : 26.62
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# airport - 시작지점(25) 까지 거리28.629662634884795 합산
# 끝지점(16) - 공항  까지 거리1.7444534347592144 합산
# total_dist :  235.13824572816822
# start :  26
# dist from 26 to 1 : 3.23
# dist from 1 to 32 : 6.22
# dist from 32 to 3 : 7.78
# dist from 3 to 14 : 1.04
# dist from 14 to 5 : 5.25
# dist from 5 to 9 : 3.89
# dist from 9 to 2 : 16.42
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 0 : 12.65
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# airport - 시작지점(26) 까지 거리43.529385349222224 합산
# 끝지점(16) - 공항  까지 거리1.7444534347592144 합산
# total_dist :  251.6144164397225
# start :  27
# dist from 27 to 12 : 0.00
# dist from 12 to 6 : 0.39
# dist from 6 to 21 : 9.33
# dist from 21 to 20 : 7.42
# dist from 20 to 8 : 1.87
# dist from 8 to 19 : 5.96
# dist from 19 to 29 : 2.31
# dist from 29 to 17 : 10.37
# dist from 17 to 33 : 0.52
# dist from 33 to 23 : 0.49
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 10 : 5.60
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 11 : 48.19
# airport - 시작지점(27) 까지 거리27.033424095975544 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  272.8159338860804
# start :  28
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 10 : 7.32
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 29 : 36.76
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# airport - 시작지점(28) 까지 거리30.34955889113739 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  277.45322626663346
# start :  29
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 17 : 21.77
# dist from 17 to 33 : 0.52
# dist from 33 to 23 : 0.49
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 10 : 5.60
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# airport - 시작지점(29) 까지 거리30.093192543332133 합산
# 끝지점(25) - 공항  까지 거리28.629662634884795 합산
# total_dist :  252.09310830586006
# start :  30
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 10 : 22.12
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# airport - 시작지점(30) 까지 거리21.68680464429302 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  253.07358920490904
# start :  31
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 0 : 4.23
# dist from 0 to 22 : 5.96
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# airport - 시작지점(31) 까지 거리15.371787854184355 합산
# 끝지점(25) - 공항  까지 거리28.629662634884795 합산
# total_dist :  252.85737401392618
# start :  32
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 3 : 12.81
# dist from 3 to 14 : 1.04
# dist from 14 to 5 : 5.25
# dist from 5 to 9 : 3.89
# dist from 9 to 25 : 17.05
# dist from 25 to 0 : 12.65
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 22 : 7.05
# dist from 22 to 30 : 2.99
# dist from 30 to 10 : 9.73
# dist from 10 to 28 : 5.60
# dist from 28 to 4 : 0.79
# dist from 4 to 23 : 0.47
# dist from 23 to 33 : 0.49
# dist from 33 to 17 : 0.52
# dist from 17 to 29 : 10.37
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# dist from 11 to 16 : 38.57
# airport - 시작지점(32) 까지 거리36.078401772418296 합산
# 끝지점(16) - 공항  까지 거리1.7444534347592144 합산
# total_dist :  239.96202269445888
# start :  33
# dist from 33 to 23 : 0.49
# dist from 23 to 4 : 0.47
# dist from 4 to 28 : 0.79
# dist from 28 to 17 : 1.79
# dist from 17 to 10 : 7.32
# dist from 10 to 30 : 9.73
# dist from 30 to 22 : 2.99
# dist from 22 to 0 : 5.96
# dist from 0 to 31 : 2.99
# dist from 31 to 15 : 1.32
# dist from 15 to 24 : 0.00
# dist from 24 to 18 : 2.43
# dist from 18 to 16 : 12.93
# dist from 16 to 5 : 24.17
# dist from 5 to 9 : 3.89
# dist from 9 to 3 : 7.15
# dist from 3 to 14 : 1.04
# dist from 14 to 32 : 8.82
# dist from 32 to 1 : 6.22
# dist from 1 to 26 : 3.23
# dist from 26 to 2 : 4.35
# dist from 2 to 13 : 3.37
# dist from 13 to 7 : 0.27
# dist from 7 to 25 : 14.20
# dist from 25 to 29 : 36.76
# dist from 29 to 19 : 2.31
# dist from 19 to 8 : 5.96
# dist from 8 to 20 : 1.87
# dist from 20 to 21 : 7.42
# dist from 21 to 12 : 9.09
# dist from 12 to 27 : 0.00
# dist from 27 to 6 : 0.39
# dist from 6 to 11 : 21.64
# airport - 시작지점(33) 까지 거리29.791503583061406 합산
# 끝지점(11) - 공항  까지 거리37.02048328138605 합산
# total_dist :  278.1697618949129
# result_index :  [9, 5, 14, 3, 32, 1, 26, 2, 13, 7, 25, 0, 31, 15, 24, 18, 22, 30, 10, 28, 4, 23, 33, 17, 29, 19, 8, 20, 21, 12, 27, 6, 11, 16]
# 조합 개수 18156204
# 조합이 너무 많으니까 path divider로 단순하게 나눌거에요~ ㅎㅎ
# length : 34
# [9, 5, 14]
# [3, 32, 1]
# [26, 2, 13, 7]
# [25, 0, 31, 15]
# [24, 18, 22, 30]
# [10, 28, 4, 23]
# [33, 17, 29, 19]
# [8, 20, 21, 12]
# [27, 6, 11, 16]
# i :  [9, 5, 14]
# j :  9
# j :  5
# j :  14
# i :  [3, 32, 1]
# j :  3
# j :  32
# j :  1
# i :  [26, 2, 13, 7]
# j :  26
# j :  2
# j :  13
# j :  7
# i :  [25, 0, 31, 15]
# j :  25
# j :  0
# j :  31
# j :  15
# i :  [24, 18, 22, 30]
# j :  24
# j :  18
# j :  22
# j :  30
# i :  [10, 28, 4, 23]
# j :  10
# j :  28
# j :  4
# j :  23
# i :  [33, 17, 29, 19]
# j :  33
# j :  17
# j :  29
# j :  19
# i :  [8, 20, 21, 12]
# j :  8
# j :  20
# j :  21
# j :  12
# i :  [27, 6, 11, 16]
# j :  27
# j :  6
# j :  11
# j :  16

# %%
a
# Out:
# [[13, 6, 30],
#  [4, 361, 2],
#  [336, 3, 29, 9],
#  [335, 1, 349, 32],
#  [334, 93, 287, 348],
#  [15, 338, 5, 333],
#  [368, 49, 339, 112],
#  [10, 154, 174, 28],
#  [337, 8, 24, 37]]
